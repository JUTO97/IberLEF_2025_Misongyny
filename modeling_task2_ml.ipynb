# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import optuna
import joblib
import multiprocessing
import json

from sklearn.model_selection import train_test_split, cross_validate, cross_val_score, GroupKFold, StratifiedGroupKFold, GroupShuffleSplit
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from collections import Counter
from utils import save_eval_results


N_JOBS = multiprocessing.cpu_count() - 1
SEED = 42
DB_PATH = "data/tfm.db" 
SUBTASK2_PATH = "new_data\\subtask2\\"

# %%
language = 'spa'
model_type = 'ml'
stemming = False
lemmatization = True
remove_duplicates = False
cased = False # Keep cased for DL models

data_config = f"lang_{language}_model_{model_type}_stem_{stemming}_lem_{lemmatization}_dup_{remove_duplicates}_cased_{cased}"
file_name = 'subtask2_all_aug'

db_file_name = '{}_{}.csv'.format(file_name, data_config)

if os.path.exists(SUBTASK2_PATH + db_file_name):
    full_data = pd.read_csv(SUBTASK2_PATH + db_file_name, encoding='utf-8')
    print('File found: ')
    print(full_data.info())
else:
    print('File not found...')    


original_data = full_data[full_data['is_augmented'] != True].copy()
original_data = original_data.sample(frac=1, random_state=SEED).reset_index(drop=True)
full_data = full_data.sample(frac=1, random_state=SEED).reset_index(drop=True)

original_data.info()
# Out:
# File found:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5840 entries, 0 to 5839
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5840 non-null   object
#  1   label              5840 non-null   object
#  2   lyrics             5840 non-null   object
#  3   lyrics_clean       5840 non-null   object
#  4   augmentation_type  5840 non-null   object
#  5   is_augmented       5840 non-null   bool
#  6   lyrics_clean_ml    5840 non-null   object
# dtypes: bool(1), object(6)
# memory usage: 279.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1168 non-null   object
#  1   label              1168 non-null   object
#  2   lyrics             1168 non-null   object
#  3   lyrics_clean       1168 non-null   object
#  4   augmentation_type  1168 non-null   object
#  5   is_augmented       1168 non-null   bool
#  6   lyrics_clean_ml    1168 non-null   object
# dtypes: bool(1), object(6)
# memory usage: 56.0+ KB

# %%
cond_aug_nr = (full_data['is_augmented'] == True) & (full_data['label'] == 'NR')
cond_aug_s = (full_data['is_augmented'] == True) & (full_data['label'] == 'S')

full_data = full_data[~(cond_aug_nr | cond_aug_s)]

# %%
full_training = True

data = original_data[['lyrics_clean_ml', 'id', 'label']].copy()
# y = original_data[['label', 'id']].copy()
groups = data['id']

if not full_training:
    gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=SEED)
    train_idx, test_idx = next(gss.split(data['lyrics_clean_ml'], data['label'], groups))

    train, test = data.iloc[train_idx], data.iloc[test_idx]
else:
    print('Full training!')
    train = original_data[['lyrics_clean_ml', 'id', 'label']].copy()
# Out:
# Full training!

# %%
train = pd.merge(train[['id']], full_data, on = "id", how = "inner").copy()
train = train.sample(frac=1, random_state=SEED).reset_index(drop=True)
train
# Out:
#                  id label                                             lyrics  \
# 0     T2_TRAIN_0352     V  [Letra de "Más viejo que tú"]\nAnoche, anoche ...
# 1     T2_TRAIN_0924     V  \n[Letra de "Kobe En LA"]\n\n[Coro]\nLa cadena...
# 2     T2_TRAIN_0746     S  \n[Letra de "Me Fallaste"]\n\nNo, no sé cómo p...
# 3     T2_TRAIN_0708    NR  s\nEl 17 de marzo\nA la ciudad de aguaprieta\n...
# 4     T2_TRAIN_0482     V  Ve por el sillón y pónselo al burro\nPónselo a...
# ...             ...   ...                                                ...
# 1991  T2_TRAIN_0251    NR  \nPersonas como tu quedan muy pocas ya\nLo sup...
# 1992  T2_TRAIN_0976    NR  s\nQue mi novia si sabe\nComo se baila la cumb...
# 1993  T2_TRAIN_1045    NR  \n[Letra de "La Mujer Que No Soñé"]\n\n[Verso ...
# 1994  T2_TRAIN_0137     V  \nSuéltame gorila, no\nQue me sueltes gorila, ...
# 1995  T2_TRAIN_0759     V  Me miraste a los ojos\nY me juraste por Dios\n...
#
#                                            lyrics_clean   augmentation_type  \
# 0     [Letra de "Más viejo que tú"]\nAnoche, anoche ...  back_translation_2
# 1     [Letra de "Kobe En LA"]\nLa cadena con la cara...            original
# 2     [Letra de "Me Fallaste"]\nNo, no sé cómo pude ...            original
# 3     El  de marzo\nA la ciudad de aguaprieta\nVino ...            original
# 4     Ve por el sillón y pónselo al burro\nPónselo a...              aeda_2
# ...                                                 ...                 ...
# 1991  Personas como tu quedan muy pocas ya\nLo supe ...            original
# 1992  Que mi novia si sabe\nComo se baila la cumbia\...            original
# 1993  [Letra de "La Mujer Que No Soñé"]\nLa de lente...            original
# 1994  Suéltame gorila, no\nQue me sueltes gorila, no...            original
# 1995  Me miraste a los ojos\nY me juraste por Dios\n...              aeda_2
#
#       is_augmented                                    lyrics_clean_ml
# 0             True  anoche anoche dormir anoche pina records soñar...
# 1            False  cadena cara jesucristo cuidar salir arrodilla ...
# 2            False  cómo poder contener yo tiempo creas cuenta dar...
# 3            False  marzo ciudad aguaprieta vino gente quiera veni...
# 4             True  sillón pon él él burro pon él él burro pon él ...
# ...            ...                                                ...
# 1991         False  persona quedar saber dia conoci bese bastante ...
# 1992         False  novia saber baila cumbia sonar tambores invito...
# 1993         False  lent pasado moda aburrido intelectual preferir...
# 1994         False  suéltame gorila soltar gorila suéltame gorila ...
# 1995          True  mirar ojo jurar dios mirar ojo jurar mamá aquí...
#
# [1996 rows x 7 columns]

# %%
X_train = train['lyrics_clean_ml']
y_train = train['label']

if not full_training:
    X_test = test['lyrics_clean_ml']
    y_test = test['label']
    groups_test = test['id']

groups_train = train['id']

# %%
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
if not full_training:
    y_test_enc = le.transform(y_test)

LABELS = le.classes_
NUM_LABELS = len(LABELS)
label2idx = {label: idx for idx, label in enumerate(LABELS)}
idx2label = {idx: label for label, idx in label2idx.items()}

print('Labels:', label2idx)

scoring = {
    'accuracy': 'accuracy',
    'precision_macro': 'precision_macro',
    'recall_macro': 'recall_macro',
    'f1_macro': 'f1_macro'
}
# Out:
# Labels: {'H': 0, 'NR': 1, 'S': 2, 'V': 3}

# %% [markdown]
# ### Model Learning (HPO - Optuna)

# %% [markdown]
# ### Random Forest

# %%
rf_pipeline = Pipeline([
        ('vect', CountVectorizer()),
        ('tfidf', TfidfTransformer()),
        ('clf', RandomForestClassifier())
])
group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)

def objective(trial):
    cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
    max_df = trial.suggest_float('vect_max_df', 0.5, 1.0)
    min_df = trial.suggest_int('vect_min_df', 1, 5)

    ngram_range_str = trial.suggest_categorical('vect_ngram_range', ["1,1", "1,2"])
    ngram_range = tuple(map(int, ngram_range_str.split(',')))

    
    use_idf = trial.suggest_categorical('tfidf_use_idf', [True, False])
    
    n_estimators = trial.suggest_int('rf_n_estimators', 100, 530)
    max_depth = trial.suggest_categorical('rf_max_depth', [None] + list(range(5, 55, 5)))
    min_samples_split = trial.suggest_int('rf_min_samples_split', 2, 15)
    min_samples_leaf = trial.suggest_int('rf_min_samples_leaf', 1, 10)
    max_features = trial.suggest_categorical('rf_max_features', ['sqrt', 'log2', None])
    criterion = trial.suggest_categorical('rf_criterion', ['gini', 'entropy', 'log_loss'])
    

    params = {
        'vect__max_df': max_df,
        'vect__min_df': min_df,
        'vect__ngram_range': ngram_range,
        'tfidf__use_idf': use_idf,
        'clf__n_estimators': n_estimators,
        'clf__max_depth': max_depth,
        'clf__min_samples_split': min_samples_split,
        'clf__min_samples_leaf': min_samples_leaf,
        'clf__max_features': max_features,
        'clf__criterion': criterion,
        'clf__class_weight': 'balanced',  
        'clf__random_state': SEED      
    }
                
    rf_pipe = rf_pipeline.set_params(**params)
    
    scores = cross_val_score(
        rf_pipe,
        X_train,
        y_train_enc,
        cv=cv,
        scoring='f1_macro',
        n_jobs=N_JOBS
    )

    return np.mean(scores)

budget = 300
rf_study_name = 'rf_optimization_{}_{}'.format(file_name, data_config) + 'new_data'
storage_name = f"sqlite:///objects/task_2/studies/{rf_study_name}.db"

rf_study = optuna.create_study(
    study_name=rf_study_name,
    storage=storage_name,
    direction="maximize",
    load_if_exists=True,  
    sampler=optuna.samplers.TPESampler(seed=SEED)  
)

rf_study.optimize(objective, n_trials=budget)


def expand_rf_params(optuna_params, seed):
    return {
        'vect__max_df': optuna_params['vect_max_df'],
        'vect__min_df': optuna_params['vect_min_df'],
        'vect__ngram_range': tuple(map(int, optuna_params['vect_ngram_range'].split(','))),
        'tfidf__use_idf': optuna_params['tfidf_use_idf'],
        'clf__n_estimators': optuna_params['rf_n_estimators'],
        'clf__max_depth': optuna_params['rf_max_depth'],
        'clf__min_samples_split': optuna_params['rf_min_samples_split'],
        'clf__min_samples_leaf': optuna_params['rf_min_samples_leaf'],
        'clf__max_features': optuna_params['rf_max_features'],
        'clf__criterion': optuna_params['rf_criterion'],
        'clf__class_weight': 'balanced',
        'clf__random_state': seed
    }

best_params_expanded = expand_rf_params(rf_study.best_params, SEED)
rf_model = rf_pipeline.set_params(**best_params_expanded)
# Out:
# [I 2025-05-07 14:44:47,330] Using an existing study with name 'rf_optimization_subtask2_all_aug_lang_spa_model_ml_stem_False_lem_True_dup_False_cased_Falsenew_data' instead of creating a new one.
# [I 2025-05-07 14:44:51,092] Trial 150 finished with value: 0.4445184478984923 and parameters: {'vect_max_df': 0.7893814067999234, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 328, 'rf_max_depth': 25, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 10, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:44:53,836] Trial 151 finished with value: 0.4464704455073977 and parameters: {'vect_max_df': 0.8217743740401856, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 329, 'rf_max_depth': 25, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:44:56,573] Trial 152 finished with value: 0.443897623803739 and parameters: {'vect_max_df': 0.8259973981740998, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 345, 'rf_max_depth': 25, 'rf_min_samples_split': 14, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:44:57,653] Trial 153 finished with value: 0.4464704455073977 and parameters: {'vect_max_df': 0.8009606583493966, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 329, 'rf_max_depth': 25, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:44:58,737] Trial 154 finished with value: 0.444435063874835 and parameters: {'vect_max_df': 0.8021812979281933, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 319, 'rf_max_depth': 25, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:44:59,915] Trial 155 finished with value: 0.4438433590831131 and parameters: {'vect_max_df': 0.8151225303483369, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 337, 'rf_max_depth': 25, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:01,023] Trial 156 finished with value: 0.44933199927522216 and parameters: {'vect_max_df': 0.8321238360879121, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 325, 'rf_max_depth': 25, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:02,164] Trial 157 finished with value: 0.3856318580237655 and parameters: {'vect_max_df': 0.8404499060726051, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 311, 'rf_max_depth': 25, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:03,219] Trial 158 finished with value: 0.4451730493763895 and parameters: {'vect_max_df': 0.831560970018067, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 347, 'rf_max_depth': 25, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:05,143] Trial 159 finished with value: 0.39385172997895124 and parameters: {'vect_max_df': 0.821652816408907, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 326, 'rf_max_depth': 25, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:06,136] Trial 160 finished with value: 0.4335493835712053 and parameters: {'vect_max_df': 0.8122267522350111, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 286, 'rf_max_depth': 25, 'rf_min_samples_split': 11, 'rf_min_samples_leaf': 10, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:07,186] Trial 161 finished with value: 0.4455822442931022 and parameters: {'vect_max_df': 0.7932750875287498, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 331, 'rf_max_depth': 25, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:08,286] Trial 162 finished with value: 0.4453776849910319 and parameters: {'vect_max_df': 0.8002597025573206, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 338, 'rf_max_depth': 25, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:09,336] Trial 163 finished with value: 0.43165192682361814 and parameters: {'vect_max_df': 0.8318306767164707, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 301, 'rf_max_depth': 20, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:10,402] Trial 164 finished with value: 0.44430173650636096 and parameters: {'vect_max_df': 0.8171895738521776, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 316, 'rf_max_depth': 25, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:11,509] Trial 165 finished with value: 0.44033380185652593 and parameters: {'vect_max_df': 0.775953104464446, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 321, 'rf_max_depth': 25, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:12,794] Trial 166 finished with value: 0.4464704455073977 and parameters: {'vect_max_df': 0.801818074797716, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 329, 'rf_max_depth': 25, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'entropy'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:13,903] Trial 167 finished with value: 0.4384204868099653 and parameters: {'vect_max_df': 0.8484940731059685, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 353, 'rf_max_depth': 10, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:14,986] Trial 168 finished with value: 0.4374431279909265 and parameters: {'vect_max_df': 0.8253586717306338, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 309, 'rf_max_depth': 40, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:16,090] Trial 169 finished with value: 0.4413107413095064 and parameters: {'vect_max_df': 0.8075130421499317, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 341, 'rf_max_depth': 25, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 10, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:17,663] Trial 170 finished with value: 0.26786723048510935 and parameters: {'vect_max_df': 0.7291873181428434, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'rf_n_estimators': 329, 'rf_max_depth': 25, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:18,735] Trial 171 finished with value: 0.4505759885868489 and parameters: {'vect_max_df': 0.7977138313962712, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 323, 'rf_max_depth': 25, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'entropy'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:19,803] Trial 172 finished with value: 0.444435063874835 and parameters: {'vect_max_df': 0.7919701308184643, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 319, 'rf_max_depth': 25, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'entropy'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:20,933] Trial 173 finished with value: 0.4438433590831131 and parameters: {'vect_max_df': 0.8362298202325069, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 337, 'rf_max_depth': 25, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'entropy'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:22,009] Trial 174 finished with value: 0.4387165975910022 and parameters: {'vect_max_df': 0.7828331440718075, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 304, 'rf_max_depth': 30, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'entropy'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:23,266] Trial 175 finished with value: 0.4499428074719109 and parameters: {'vect_max_df': 0.8132933250300409, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 326, 'rf_max_depth': 25, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'entropy'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:24,321] Trial 176 finished with value: 0.43533248069458513 and parameters: {'vect_max_df': 0.8127485114852617, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 295, 'rf_max_depth': 25, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'entropy'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:25,471] Trial 177 finished with value: 0.44311370600868216 and parameters: {'vect_max_df': 0.8379101854009705, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 350, 'rf_max_depth': None, 'rf_min_samples_split': 11, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'entropy'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:45:26,521] Trial 178 finished with value: 0.4399442906688015 and parameters: {'vect_max_df': 0.8199712176991176, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 313, 'rf_max_depth': 25, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'entropy'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:46:37,253] Trial 179 finished with value: 0.3931663532909542 and parameters: {'vect_max_df': 0.8266554890200459, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 322, 'rf_max_depth': 25, 'rf_min_samples_split': 11, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_criterion': 'entropy'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:46:38,345] Trial 180 finished with value: 0.4408131990452989 and parameters: {'vect_max_df': 0.7683120642555825, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 344, 'rf_max_depth': 25, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 10, 'rf_max_features': 'log2', 'rf_criterion': 'entropy'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:46:39,483] Trial 181 finished with value: 0.4496661774120724 and parameters: {'vect_max_df': 0.8042289041214052, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 328, 'rf_max_depth': 25, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:46:40,593] Trial 182 finished with value: 0.4455822442931022 and parameters: {'vect_max_df': 0.8051643049613925, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 331, 'rf_max_depth': 25, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:46:41,639] Trial 183 finished with value: 0.45009561592843095 and parameters: {'vect_max_df': 0.7890100740761965, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 322, 'rf_max_depth': 25, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:46:42,743] Trial 184 finished with value: 0.4311649365384877 and parameters: {'vect_max_df': 0.7869111518848059, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 308, 'rf_max_depth': 50, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:46:43,787] Trial 185 finished with value: 0.444435063874835 and parameters: {'vect_max_df': 0.7746053521339202, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 319, 'rf_max_depth': 25, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_criterion': 'entropy'}. Best is trial 113 with value: 0.4505759885868489.
# [I 2025-05-07 14:46:44,869] Trial 186 finished with value: 0.4519964375970278 and parameters: {'vect_max_df': 0.7939933181333475, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 338, 'rf_max_depth': 25, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 186 with value: 0.4519964375970278.
# [I 2025-05-07 14:46:45,973] Trial 187 finished with value: 0.45275951464409336 and parameters: {'vect_max_df': 0.8113289514957858, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 337, 'rf_max_depth': 40, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 187 with value: 0.45275951464409336.
# [I 2025-05-07 14:46:47,134] Trial 188 finished with value: 0.45055149933149224 and parameters: {'vect_max_df': 0.7967822597279374, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 342, 'rf_max_depth': 40, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 187 with value: 0.45275951464409336.
# [I 2025-05-07 14:46:48,287] Trial 189 finished with value: 0.4519964375970278 and parameters: {'vect_max_df': 0.7927349753523989, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 338, 'rf_max_depth': 40, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 187 with value: 0.45275951464409336.
# [I 2025-05-07 14:46:49,427] Trial 190 finished with value: 0.4508230703422507 and parameters: {'vect_max_df': 0.7969653924220881, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 340, 'rf_max_depth': 15, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 187 with value: 0.45275951464409336.
# [I 2025-05-07 14:46:50,486] Trial 191 finished with value: 0.4543109244752886 and parameters: {'vect_max_df': 0.794049792388566, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 340, 'rf_max_depth': 40, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 191 with value: 0.4543109244752886.
# [I 2025-05-07 14:46:51,595] Trial 192 finished with value: 0.4479928463814966 and parameters: {'vect_max_df': 0.795037528611892, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 356, 'rf_max_depth': 40, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 191 with value: 0.4543109244752886.
# [I 2025-05-07 14:46:52,736] Trial 193 finished with value: 0.45558522231680965 and parameters: {'vect_max_df': 0.791999184954188, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 341, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 193 with value: 0.45558522231680965.
# [I 2025-05-07 14:46:53,834] Trial 194 finished with value: 0.4543109244752886 and parameters: {'vect_max_df': 0.7912036044925469, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 340, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 193 with value: 0.45558522231680965.
# [I 2025-05-07 14:46:54,985] Trial 195 finished with value: 0.44935259819588047 and parameters: {'vect_max_df': 0.7947983518794866, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 345, 'rf_max_depth': 40, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 193 with value: 0.45558522231680965.
# [I 2025-05-07 14:46:56,123] Trial 196 finished with value: 0.44827954897705596 and parameters: {'vect_max_df': 0.7833569402068936, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 360, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 193 with value: 0.45558522231680965.
# [I 2025-05-07 14:46:57,284] Trial 197 finished with value: 0.454288419441317 and parameters: {'vect_max_df': 0.7908470663655921, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 347, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 193 with value: 0.45558522231680965.
# [I 2025-05-07 14:46:59,395] Trial 198 finished with value: 0.38691299560742526 and parameters: {'vect_max_df': 0.791102170851158, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 347, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 193 with value: 0.45558522231680965.
# [I 2025-05-07 14:47:00,508] Trial 199 finished with value: 0.45558522231680965 and parameters: {'vect_max_df': 0.7741396931075486, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 341, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 193 with value: 0.45558522231680965.
# [I 2025-05-07 14:47:01,595] Trial 200 finished with value: 0.4512989067979037 and parameters: {'vect_max_df': 0.7729428277934711, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 339, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 193 with value: 0.45558522231680965.
# [I 2025-05-07 14:47:02,704] Trial 201 finished with value: 0.45055149933149224 and parameters: {'vect_max_df': 0.772129056699997, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 342, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 193 with value: 0.45558522231680965.
# [I 2025-05-07 14:47:03,787] Trial 202 finished with value: 0.4512989067979037 and parameters: {'vect_max_df': 0.7670749701604879, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 339, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 193 with value: 0.45558522231680965.
# [I 2025-05-07 14:47:04,897] Trial 203 finished with value: 0.4543109244752886 and parameters: {'vect_max_df': 0.7647551171760167, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 340, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 193 with value: 0.45558522231680965.
# [I 2025-05-07 14:47:06,019] Trial 204 finished with value: 0.4496306690240834 and parameters: {'vect_max_df': 0.7571682426974409, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators':
finished with value: 0.4565561672029398 and parameters: {'vect_max_df': 0.7254246487171551, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 349, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:48:57,143] Trial 238 finished with value: 0.4492095942842599 and parameters: {'vect_max_df': 0.7273269020503458, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 365, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:48:58,272] Trial 239 finished with value: 0.4570130326994774 and parameters: {'vect_max_df': 0.7194163501132503, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 348, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:00,420] Trial 240 finished with value: 0.38759621408953515 and parameters: {'vect_max_df': 0.7211015695154068, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 349, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:01,515] Trial 241 finished with value: 0.4565561672029398 and parameters: {'vect_max_df': 0.7311354372675601, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 349, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:02,746] Trial 242 finished with value: 0.449963105304015 and parameters: {'vect_max_df': 0.7394499799598451, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 359, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:03,978] Trial 243 finished with value: 0.454288419441317 and parameters: {'vect_max_df': 0.7296572921334028, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 347, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:05,194] Trial 244 finished with value: 0.4565561672029398 and parameters: {'vect_max_df': 0.7284086722217678, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 349, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:06,393] Trial 245 finished with value: 0.4565561672029398 and parameters: {'vect_max_df': 0.7284104397893982, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 349, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:07,520] Trial 246 finished with value: 0.4571247168918101 and parameters: {'vect_max_df': 0.72051476540831, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 350, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:08,720] Trial 247 finished with value: 0.45156905089373256 and parameters: {'vect_max_df': 0.7152958261761827, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 373, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:09,955] Trial 248 finished with value: 0.449963105304015 and parameters: {'vect_max_df': 0.7213785058859147, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 359, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:11,137] Trial 249 finished with value: 0.4501330612338725 and parameters: {'vect_max_df': 0.7058743767938664, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 352, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:12,379] Trial 250 finished with value: 0.43301627485558497 and parameters: {'vect_max_df': 0.7217840544915256, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 367, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:13,967] Trial 251 finished with value: 0.30953366136621413 and parameters: {'vect_max_df': 0.7325887545094472, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'rf_n_estimators': 351, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:15,253] Trial 252 finished with value: 0.4488682709197061 and parameters: {'vect_max_df': 0.7583093233403182, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 358, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:16,405] Trial 253 finished with value: 0.454288419441317 and parameters: {'vect_max_df': 0.7322500359393078, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 347, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:17,553] Trial 254 finished with value: 0.4488682709197061 and parameters: {'vect_max_df': 0.7577680658327518, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 358, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:18,684] Trial 255 finished with value: 0.43264369389998575 and parameters: {'vect_max_df': 0.7388984913200205, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 351, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'gini'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:19,895] Trial 256 finished with value: 0.4453500427774692 and parameters: {'vect_max_df': 0.7185433869999643, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 369, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 7, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:21,143] Trial 257 finished with value: 0.4422596179479307 and parameters: {'vect_max_df': 0.7586967375256378, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 383, 'rf_max_depth': 40, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 7, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:22,295] Trial 258 finished with value: 0.454288419441317 and parameters: {'vect_max_df': 0.7109758282377074, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 347, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:49:23,465] Trial 259 finished with value: 0.4374918595458322 and parameters: {'vect_max_df': 0.6921163590157516, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 359, 'rf_max_depth': 40, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:40,483] Trial 260 finished with value: 0.3860102100372684 and parameters: {'vect_max_df': 0.7299551838395144, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 348, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:41,673] Trial 261 finished with value: 0.44742397777949333 and parameters: {'vect_max_df': 0.7584361428208325, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 364, 'rf_max_depth': 40, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:42,794] Trial 262 finished with value: 0.45120541064419123 and parameters: {'vect_max_df': 0.7745683756920114, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 346, 'rf_max_depth': 40, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:43,898] Trial 263 finished with value: 0.45023635150515445 and parameters: {'vect_max_df': 0.7431271022641089, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 354, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:44,997] Trial 264 finished with value: 0.45120541064419123 and parameters: {'vect_max_df': 0.7786598973268068, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 346, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:46,254] Trial 265 finished with value: 0.42948387318990083 and parameters: {'vect_max_df': 0.7287836449001955, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 355, 'rf_max_depth': 40, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:47,413] Trial 266 finished with value: 0.4492095942842599 and parameters: {'vect_max_df': 0.7605998430315029, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 365, 'rf_max_depth': 40, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:49,674] Trial 267 finished with value: 0.3884187955971811 and parameters: {'vect_max_df': 0.7539133290857134, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 376, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:50,753] Trial 268 finished with value: 0.44935259819588047 and parameters: {'vect_max_df': 0.7020980479961566, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 345, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:52,463] Trial 269 finished with value: 0.30882327661649966 and parameters: {'vect_max_df': 0.7430262716132291, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'rf_n_estimators': 355, 'rf_max_depth': 40, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:53,643] Trial 270 finished with value: 0.42817188024163305 and parameters: {'vect_max_df': 0.7353484250855775, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 346, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:54,823] Trial 271 finished with value: 0.4188699259880166 and parameters: {'vect_max_df': 0.6285567643426768, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 334, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:55,939] Trial 272 finished with value: 0.4473168177505184 and parameters: {'vect_max_df': 0.7685667775321665, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 362, 'rf_max_depth': 40, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 7, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:57,104] Trial 273 finished with value: 0.387998094956816 and parameters: {'vect_max_df': 0.7174193887679541, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 344, 'rf_max_depth': 5, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:58,223] Trial 274 finished with value: 0.4516383766903017 and parameters: {'vect_max_df': 0.7778844731919463, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 351, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:50:59,393] Trial 275 finished with value: 0.4444473805788694 and parameters: {'vect_max_df': 0.7590780323048207, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 371, 'rf_max_depth': 40, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'gini'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:51:00,634] Trial 276 finished with value: 0.416414090654938 and parameters: {'vect_max_df': 0.7409989289007728, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 334, 'rf_max_depth': 20, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:51:01,789] Trial 277 finished with value: 0.4504232458276488 and parameters: {'vect_max_df': 0.7505467767863311, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 357, 'rf_max_depth': 40, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:51:02,891] Trial 278 finished with value: 0.4537510477628793 and parameters: {'vect_max_df': 0.7297951670083561, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 344, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:51:04,005] Trial 279 finished with value: 0.45265986393826596 and parameters: {'vect_max_df': 0.7781393068351068, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 333, 'rf_max_depth': 35, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:51:05,083] Trial 280 finished with value: 0.45055149933149224 and parameters: {'vect_max_df': 0.7692572864689963, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 342, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:51:06,267] Trial 281 finished with value: 0.44932881597879604 and parameters: {'vect_max_df': 0.7241307935386624, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 355, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 7, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:51:07,473] Trial 282 finished with value: 0.4485470972317674 and parameters: {'vect_max_df': 0.762855090448723, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 362, 'rf_max_depth': 10, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:12,774] Trial 283 finished with value: 0.3712963390089088 and parameters: {'vect_max_df': 0.7444048592339709, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 350, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:14,225] Trial 284 finished with value: 0.45265986393826596 and parameters: {'vect_max_df': 0.7124631631134636, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 333, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:16,692] Trial 285 finished with value: 0.3347084752869138 and parameters: {'vect_max_df': 0.7817148577504568, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 343, 'rf_max_depth': 40, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:18,173] Trial 286 finished with value: 0.4501330612338725 and parameters: {'vect_max_df': 0.7549181870903247, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 352, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:19,755] Trial 287 finished with value: 0.4467874756649525 and parameters: {'vect_max_df': 0.7367234974547988, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 368, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 7, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:21,345] Trial 288 finished with value: 0.42797954788029413 and parameters: {'vect_max_df': 0.7668013975055138, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 343, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:26,333] Trial 289 finished with value: 0.3861126154383682 and parameters: {'vect_max_df': 0.7499468885215504, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'rf_n_estimators': 334, 'rf_max_depth': 40, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:27,524] Trial 290 finished with value: 0.449963105304015 and parameters: {'vect_max_df': 0.7220284413247132, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 359, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:28,694] Trial 291 finished with value: 0.4565561672029398 and parameters: {'vect_max_df': 0.9671263578899713, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 349, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:29,983] Trial 292 finished with value: 0.4478285316996938 and parameters: {'vect_max_df': 0.704257877385066, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 378, 'rf_max_depth': 50, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:31,193] Trial 293 finished with value: 0.4489943314012235 and parameters: {'vect_max_df': 0.7289996895224289, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 334, 'rf_max_depth': 40, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:32,413] Trial 294 finished with value: 0.3992899536483263 and parameters: {'vect_max_df': 0.7624525814247267, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 353, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:33,575] Trial 295 finished with value: 0.45281814285147426 and parameters: {'vect_max_df': 0.9460186592928544, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 343, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:34,754] Trial 296 finished with value: 0.4227922438950297 and parameters: {'vect_max_df': 0.5065076621739502, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 364, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:36,025] Trial 297 finished with value: 0.43249408245141685 and parameters: {'vect_max_df': 0.9675000121316812, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 341, 'rf_max_depth': 15, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'gini'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:37,238] Trial 298 finished with value: 0.451202907002341 and parameters: {'vect_max_df': 0.7385561321045646, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 353, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.
# [I 2025-05-07 14:53:38,439] Trial 299 finished with value: 0.45086639947853974 and parameters: {'vect_max_df': 0.7742462896787989, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 332, 'rf_max_depth': 40, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 226 with value: 0.45765915398137114.

# %%
group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
cv_results = cross_validate(rf_model, X_train, y_train_enc, cv=cv, scoring=scoring, n_jobs=N_JOBS)

rf_model.fit(X_train, y_train_enc)

acc = np.mean(cv_results['test_accuracy'])
pre = np.mean(cv_results['test_precision_macro'])
rec = np.mean(cv_results['test_recall_macro'])
f1_ = np.mean(cv_results['test_f1_macro'])

rf_best_trial = rf_study.best_trial
print("Best trial Cross-Validation results on the training set for Random Forest:")
print(f"  Accuracy:  {acc:.4f}")
print(f"  Precision: {pre:.4f}")
print(f"  Recall:    {rec:.4f}")
print(f"  F1:        {f1_:.4f}")

print("Best hyperparameters:")
for key, value in rf_best_trial.params.items():
    print(f"  {key}: {value}")

model_filename = 'objects/task_2/models/best_rf_{}_{}.pkl'.format(file_name, data_config)
joblib.dump(rf_model, model_filename)
print(f"Random Forest model saved as {model_filename}.")

task_val   = "task_2"
model_name = "Random Forest"
eval_type  = "inner"

save_eval_results(DB_PATH, db_file_name, task_val, model_name, eval_type, acc, pre, rec, f1_, rf_study_name, json.dumps(rf_study.best_params), language)
# Out:
# Best trial Cross-Validation results on the training set for Random Forest:
#   Accuracy:  0.4755
#   Precision: 0.4914
#   Recall:    0.4948
#   F1:        0.4577
# Best hyperparameters:
#   vect_max_df: 0.7359264039121303
#   vect_min_df: 1
#   vect_ngram_range: 1,1
#   tfidf_use_idf: False
#   rf_n_estimators: 336
#   rf_max_depth: 40
#   rf_min_samples_split: 6
#   rf_min_samples_leaf: 8
#   rf_max_features: log2
#   rf_criterion: log_loss
# Random Forest model saved as objects/task_2/models/best_rf_subtask2_all_aug_lang_spa_model_ml_stem_False_lem_True_dup_False_cased_False.pkl.
#
# Inserted CV results into 'eval' table in tfm.db.

# %% [markdown]
# ### SVM (Best Model)

# %%
svm_pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', SVC())
])
group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
def svm_objective(trial):
    cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
    max_df = trial.suggest_float('vect_max_df', 0.5, 1.0)
    min_df = trial.suggest_int('vect_min_df', 1, 5)
    
    ngram_range_str = trial.suggest_categorical('vect_ngram_range', ["1,1", "1,2"])
    ngram_range = tuple(map(int, ngram_range_str.split(',')))
    
    use_idf = trial.suggest_categorical('tfidf_use_idf', [True, False])
    norm = trial.suggest_categorical('tfidf_norm', ['l1', 'l2', None]) 
    
    C = trial.suggest_float('svm_C', 1e-3, 10, log=True)
    kernel = trial.suggest_categorical('svm_kernel', ['linear', 'rbf', 'sigmoid', 'poly'])
    shrinking = trial.suggest_categorical('svm_shrinking', [True, False]) 
    
    params = {
        'vect__max_df': max_df,
        'vect__min_df': min_df,
        'vect__ngram_range': ngram_range,
        'tfidf__use_idf': use_idf,
        'tfidf__norm': norm, 
        'clf__C': C,
        'clf__kernel': kernel,
        'clf__shrinking': shrinking, 
        'clf__class_weight': 'balanced',
        'clf__random_state': SEED  
    }
    
    if kernel != 'linear':
        gamma = trial.suggest_float('svm_gamma', 1e-4, 1, log=True)
        params['clf__gamma'] = gamma
    if kernel == 'poly':
        params['clf__degree'] = trial.suggest_int('svm_degree', 2, 5)
        params['clf__coef0'] = trial.suggest_float('svm_coef0', 0.0, 1.0)
    
    svm_pipe = svm_pipeline.set_params(**params)
    
    scores = cross_val_score(svm_pipe, X_train, y_train_enc, cv=cv, scoring='f1_macro', n_jobs=N_JOBS)
    return scores.mean()

svm_study_name = 'svm_optimization_{}_{}'.format(file_name,data_config) + '_full_training' if full_training else ''
storage_name = f"sqlite:///objects/task_2/studies/{svm_study_name}.db"

svm_study = optuna.create_study(
    study_name=svm_study_name,
    storage=storage_name,
    direction="maximize",
    load_if_exists=True,
    sampler=optuna.samplers.TPESampler(seed=SEED)
)

budget = 350
svm_study.optimize(svm_objective, n_trials=budget)

best_params = svm_study.best_params

def expand_svm_params(optuna_params, seed):
    expanded = {
        'vect__max_df': optuna_params['vect_max_df'],
        'vect__min_df': optuna_params['vect_min_df'],
        'vect__ngram_range': tuple(map(int, optuna_params['vect_ngram_range'].split(','))),
        'tfidf__use_idf': optuna_params['tfidf_use_idf'],
        'tfidf__norm': optuna_params['tfidf_norm'],
        'clf__C': optuna_params['svm_C'],
        'clf__kernel': optuna_params['svm_kernel'],
        'clf__shrinking': optuna_params['svm_shrinking'],
        'clf__class_weight': 'balanced',
        'clf__random_state': seed
    }

    if optuna_params['svm_kernel'] != 'linear':
        expanded['clf__gamma'] = optuna_params['svm_gamma']
    if optuna_params['svm_kernel'] == 'poly':
        expanded['clf__degree'] = optuna_params['svm_degree']
        expanded['clf__coef0'] = optuna_params['svm_coef0']

    return expanded

best_params_expanded = expand_svm_params(svm_study.best_params, SEED)
svm_model = svm_pipeline.set_params(**best_params_expanded)
# Out:
# [I 2025-05-12 01:32:29,119] Using an existing study with name 'svm_optimization_subtask2_all_aug_lang_spa_model_ml_stem_False_lem_True_dup_False_cased_False_full_training' instead of creating a new one.
# [I 2025-05-12 01:32:32,466] Trial 300 finished with value: 0.4045086706811808 and parameters: {'vect_max_df': 0.5008714720306161, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.6662068962647606, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.706621536364163}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:32:35,575] Trial 301 finished with value: 0.43073700278111177 and parameters: {'vect_max_df': 0.5214426705353511, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.37523607377210383, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.9986641977048709}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:32:38,685] Trial 302 finished with value: 0.4207193182949637 and parameters: {'vect_max_df': 0.5088712174264223, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.47880587859934626, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.8183768063255589}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:32:41,317] Trial 303 finished with value: 0.40134938317216634 and parameters: {'vect_max_df': 0.5362283974962896, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.7765137086821255, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.9985593233402895}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:32:43,761] Trial 304 finished with value: 0.22033628699128846 and parameters: {'vect_max_df': 0.5002865513666138, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': None, 'svm_C': 0.5356277454065308, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.7050787569008566}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:32:47,532] Trial 305 finished with value: 0.3409876877545835 and parameters: {'vect_max_df': 0.5191904719898559, 'vect_min_df': 5, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.6613058001016084, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.8294510453612122}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:32:50,045] Trial 306 finished with value: 0.3641720127136781 and parameters: {'vect_max_df': 0.5090059057329867, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.9953754602385326, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:32:53,160] Trial 307 finished with value: 0.35573826162654526 and parameters: {'vect_max_df': 0.5278139048753743, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.4175695296064157, 'svm_kernel': 'rbf', 'svm_shrinking': False, 'svm_gamma': 0.6617922641337779}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:32:56,481] Trial 308 finished with value: 0.1152591809579043 and parameters: {'vect_max_df': 0.5188183732888025, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.0029676745984187434, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.8141016438006264}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:32:59,105] Trial 309 finished with value: 0.3943811020009479 and parameters: {'vect_max_df': 0.5089156383250842, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.8134900968841366, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.9987459089665414}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:02,064] Trial 310 finished with value: 0.40552128517407954 and parameters: {'vect_max_df': 0.5166743794127068, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.6022922773987625, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.6279906307279356}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:05,225] Trial 311 finished with value: 0.4348449668972534 and parameters: {'vect_max_df': 0.5009018677736019, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.3111780536186796, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.8345448092152891}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:08,714] Trial 312 finished with value: 0.09694318614801659 and parameters: {'vect_max_df': 0.5318038434760856, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.49207670483447996, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.018417918693100277}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:11,796] Trial 313 finished with value: 0.4034352388264055 and parameters: {'vect_max_df': 0.5095222102488266, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.740845778806494, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.8464448642207417}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:16,444] Trial 314 finished with value: 0.42844753026519855 and parameters: {'vect_max_df': 0.5231625173555837, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.0093571062327404, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.10387408296597256}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:20,645] Trial 315 finished with value: 0.08403493591551 and parameters: {'vect_max_df': 0.5089308608328794, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5793173021974846, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.00021454709998876067}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:23,936] Trial 316 finished with value: 0.39751763770337595 and parameters: {'vect_max_df': 0.5000927962571576, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.8646879821702742, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.6912067994399343}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:27,369] Trial 317 finished with value: 0.4007964177569755 and parameters: {'vect_max_df': 0.5185050867038559, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.6818750059018694, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.9937939746366101}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:31,286] Trial 318 finished with value: 0.0986871757516553 and parameters: {'vect_max_df': 0.5381155520696612, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.44356151841126146, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.013607254379593604}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:34,595] Trial 319 finished with value: 0.3118568135443964 and parameters: {'vect_max_df': 0.5282283303154198, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.0229244203609074, 'svm_kernel': 'poly', 'svm_shrinking': False, 'svm_gamma': 0.7243271147272532, 'svm_degree': 2, 'svm_coef0': 0.3428246724813539}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:38,034] Trial 320 finished with value: 0.43763500364805025 and parameters: {'vect_max_df': 0.5104444457707314, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5461585982653261, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.8364926115363144}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:41,101] Trial 321 finished with value: 0.42742710845709475 and parameters: {'vect_max_df': 0.5178254057887911, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.7738568725763406, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.6140065623662603}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:44,601] Trial 322 finished with value: 0.09925498131962372 and parameters: {'vect_max_df': 0.5089362304425826, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l1', 'svm_C': 0.6339409660727262, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.8356357787661604}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:47,940] Trial 323 finished with value: 0.4447280570938942 and parameters: {'vect_max_df': 0.5002721520239721, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.36914672075105587, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.7225027631219214}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:50,756] Trial 324 finished with value: 0.4289321767228459 and parameters: {'vect_max_df': 0.5276626722197136, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.866269538131127, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.985495738553081}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:54,605] Trial 325 finished with value: 0.20461403967921393 and parameters: {'vect_max_df': 0.5167635588994233, 'vect_min_df': 5, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': None, 'svm_C': 0.47789310850596295, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.6107313709036188}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:33:57,567] Trial 326 finished with value: 0.4386870865674933 and parameters: {'vect_max_df': 0.5005444214376736, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.7018616103289039, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.9985521222780287}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:00,614] Trial 327 finished with value: 0.43521924444584226 and parameters: {'vect_max_df': 0.5382561057495205, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5909546331252135, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.8321823539794683}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:03,517] Trial 328 finished with value: 0.4083766887454111 and parameters: {'vect_max_df': 0.5171971336373916, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.0574276565287481, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.7230047488910192}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:06,331] Trial 329 finished with value: 0.4285014425083421 and parameters: {'vect_max_df': 0.509648733907532, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.8073987587633351, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.8704825243688791}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:09,695] Trial 330 finished with value: 0.10926264926002094 and parameters: {'vect_max_df': 0.5255293615947713, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5092471559245358, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.02698196765614385}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:12,513] Trial 331 finished with value: 0.37907467486491353 and parameters: {'vect_max_df': 0.5003485301002973, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.6380549051103093, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:15,563] Trial 332 finished with value: 0.29847542175556985 and parameters: {'vect_max_df': 0.510740801202505, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.90686024892208, 'svm_kernel': 'rbf', 'svm_shrinking': False, 'svm_gamma': 0.9980040113479521}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:19,097] Trial 333 finished with value: 0.4357619438702889 and parameters: {'vect_max_df': 0.5223091261505749, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.39887207254939805, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.6063063513366472}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:22,175] Trial 334 finished with value: 0.4330443554368296 and parameters: {'vect_max_df': 0.5097521420223543, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.697369067579557, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.7237349752467586}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:25,674] Trial 335 finished with value: 0.4328670656497776 and parameters: {'vect_max_df': 0.5336560033692517, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.27776693133943375, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.8307993690092352}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:28,666] Trial 336 finished with value: 0.44118846072253 and parameters: {'vect_max_df': 0.5184219853372778, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5265122247876014, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.8515320805412585}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:31,448] Trial 337 finished with value: 0.40769892154651827 and parameters: {'vect_max_df': 0.5085958594400686, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.0494375069781297, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.6659326727883933}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:34,864] Trial 338 finished with value: 0.4425513370223513 and parameters: {'vect_max_df': 0.500548849510647, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.7777930704628369, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.1532578321334819}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:38,020] Trial 339 finished with value: 0.4383772862424523 and parameters: {'vect_max_df': 0.526333173604617, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.436376164825303, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.8131576141615994}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:40,955] Trial 340 finished with value: 0.44440936613199417 and parameters: {'vect_max_df': 0.500029089309925, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.6001985056339171, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.9881576369937886}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:44,031] Trial 341 finished with value: 0.4285413057980689 and parameters: {'vect_max_df': 0.5167054797240924, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.7397552594035974, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.5643260022411085}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:46,866] Trial 342 finished with value: 0.4234339935714345 and parameters: {'vect_max_df': 0.5401919389205168, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.9319471818116742, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.9974506788075386}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:50,016] Trial 343 finished with value: 0.44058605339343115 and parameters: {'vect_max_df': 0.51215424824611, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5227075907939316, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.7073222890859782}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:54,454] Trial 344 finished with value: 0.2736197702492932 and parameters: {'vect_max_df': 0.5303122191674049, 'vect_min_df': 5, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l1', 'svm_C': 1.1186126771429503, 'svm_kernel': 'poly', 'svm_shrinking': False, 'svm_gamma': 0.8086954661848312, 'svm_degree': 4, 'svm_coef0': 0.8377004100786464}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:34:57,668] Trial 345 finished with value: 0.4521633202309559 and parameters: {'vect_max_df': 0.5188012264620006, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.6847401937064459, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.9984738047979995}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:35:01,364] Trial 346 finished with value: 0.10528292183935026 and parameters: {'vect_max_df': 0.5206066053468441, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.022765921898045105, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.7209359941891903}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:35:04,751] Trial 347 finished with value: 0.4465880378822841 and parameters: {'vect_max_df': 0.5001883612138922, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.7747143654468674, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.6023162270750352}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:35:08,115] Trial 348 finished with value: 0.44133106975939995 and parameters: {'vect_max_df': 0.5086106293348787, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.7205847782308308, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.5893661817610295}. Best is trial 239 with value: 0.4533098926349906.
# [I 2025-05-12 01:35:11,420] Trial 349 finished with value: 0.19117323153106724 and parameters: {'vect_max_df': 0.5296482172705362, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': None, 'svm_C': 0.4509230145777428, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.5509871915112907}. Best is trial 239 with value: 0.4533098926349906.

# %%
if not full_training:
    group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
    cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
    cv_results = cross_validate(svm_model, X_train, y_train_enc, cv=cv, scoring=scoring, n_jobs=N_JOBS)
    svm_model.fit(X_train, y_train_enc)

    acc = np.mean(cv_results['test_accuracy'])
    pre = np.mean(cv_results['test_precision_macro'])
    rec = np.mean(cv_results['test_recall_macro'])
    f1_ = np.mean(cv_results['test_f1_macro'])

    svm_best_trial = svm_study.best_trial
    print("Best trial Cross-Validation results on the training set for SVM:")
    print(f"  Accuracy:  {acc:.4f}")
    print(f"  Precision: {pre:.4f}")
    print(f"  Recall:    {rec:.4f}")
    print(f"  F1:        {f1_:.4f}")


    print("Best hyperparameters:")
    for key, value in svm_best_trial.params.items():
        print("  {}: {}".format(key, value))


    task_val = "task_2"
    model_name   = "SVM"
    eval_type   = "inner"  

    save_eval_results(DB_PATH, db_file_name,task_val, model_name, eval_type,  acc, pre, rec, f1_, svm_study_name, json.dumps(svm_study.best_params), language)
else:
    svm_model.fit(X_train, y_train_enc)

    svm_best_trial = svm_study.best_trial

    print("Best hyperparameters:")
    for key, value in svm_best_trial.params.items():
        print("  {}: {}".format(key, value))

full_data_config =  data_config + '_full_training' if full_training else ''
model_filename = 'objects/task_2/models/best_svm_{}_{}.pkl'.format(file_name, full_data_config)
joblib.dump(svm_model, model_filename)
print("SVM model saved as {}.".format(model_filename))
# Out:
# Best hyperparameters:
#   vect_max_df: 0.5109089106538789
#   vect_min_df: 5
#   vect_ngram_range: 1,1
#   tfidf_use_idf: False
#   tfidf_norm: l2
#   svm_C: 0.9178685792438757
#   svm_kernel: sigmoid
#   svm_shrinking: False
#   svm_gamma: 0.9896267404392098
# SVM model saved as objects/task_2/models/best_svm_subtask2_all_aug_lang_spa_model_ml_stem_False_lem_True_dup_False_cased_False_full_training.pkl.

# %% [markdown]
# ### XGBoost

# %%
# Compute scale_pos_weight for XGBoost 
counter = Counter(y_train)
majority = max(counter.values())
minority = min(counter.values())
scale_pos_weight = majority / minority

# %%
xgb_pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', XGBClassifier(use_label_encoder=False, eval_metric='logloss'))
])
group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
def xgb_objective(trial):
    
    cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
    max_df = trial.suggest_float('vect_max_df', 0.5, 1.0)
    min_df = trial.suggest_int('vect_min_df', 1, 5)
    ngram_range_str = trial.suggest_categorical('vect_ngram_range', ["1,1", "1,2"])
    ngram_range = tuple(map(int, ngram_range_str.split(',')))
    
    use_idf = trial.suggest_categorical('tfidf_use_idf', [True, False])
    
    n_estimators = trial.suggest_int('xgb_n_estimators', 50, 500)
    max_depth = trial.suggest_int('xgb_max_depth', 3, 15)
    learning_rate = trial.suggest_float('xgb_learning_rate', 0.001, 0.3, log=True)
    subsample = trial.suggest_float('xgb_subsample', 0.5, 1.0)
    colsample_bytree = trial.suggest_float('xgb_colsample_bytree', 0.5, 1.0)
    reg_alpha = trial.suggest_float('xgb_reg_alpha', 1e-8, 1.0, log=True)
    reg_lambda = trial.suggest_float('xgb_reg_lambda', 1e-8, 1.0, log=True)
    
    params = {
        'vect__max_df': max_df,
        'vect__min_df': min_df,
        'vect__ngram_range': ngram_range,
        'tfidf__use_idf': use_idf,
        'clf__n_estimators': n_estimators,
        'clf__max_depth': max_depth,
        'clf__learning_rate': learning_rate,
        'clf__subsample': subsample,
        'clf__colsample_bytree': colsample_bytree,
        'clf__reg_alpha': reg_alpha,
        'clf__reg_lambda': reg_lambda,
        'clf__scale_pos_weight': scale_pos_weight, 
        'clf__random_state': SEED
    }
    
    xgb_pipe = xgb_pipeline.set_params(**params)
    
    scores = cross_val_score(xgb_pipe, X_train, y_train_enc, cv=cv, scoring='f1_macro', n_jobs=N_JOBS)
    return scores.mean()

xgb_study_name = 'xgb_optimization_{}_{}'.format(file_name, data_config) + 'new_data'
storage_name = f"sqlite:///objects/task_2/studies/{xgb_study_name}.db"
xgb_study = optuna.create_study(
    study_name=xgb_study_name,
    storage=storage_name,
    direction="maximize",
    load_if_exists=True,
    sampler=optuna.samplers.TPESampler(seed=SEED)
)

budget = 220
xgb_study.optimize(xgb_objective, n_trials=budget)

# Function to expand flat Optuna parameters into pipeline keys
def expand_xgb_params(optuna_params, seed):
    return {
        'vect__max_df': optuna_params['vect_max_df'],
        'vect__min_df': optuna_params['vect_min_df'],
        'vect__ngram_range': tuple(map(int, optuna_params['vect_ngram_range'].split(','))),
        'tfidf__use_idf': optuna_params['tfidf_use_idf'],
        'clf__n_estimators': optuna_params['xgb_n_estimators'],
        'clf__max_depth': optuna_params['xgb_max_depth'],
        'clf__learning_rate': optuna_params['xgb_learning_rate'],
        'clf__subsample': optuna_params['xgb_subsample'],
        'clf__colsample_bytree': optuna_params['xgb_colsample_bytree'],
        'clf__reg_alpha': optuna_params['xgb_reg_alpha'],
        'clf__reg_lambda': optuna_params['xgb_reg_lambda'],
        'clf__scale_pos_weight': scale_pos_weight,
        'clf__random_state': seed
    }

best_params_expanded = expand_xgb_params(xgb_study.best_params, SEED)
xgb_model = xgb_pipeline.set_params(**best_params_expanded)
# Out:
# [I 2025-05-07 16:23:41,602] Using an existing study with name 'xgb_optimization_subtask2_all_aug_lang_spa_model_ml_stem_False_lem_True_dup_False_cased_Falsenew_data' instead of creating a new one.
# [I 2025-05-07 16:24:22,364] Trial 121 finished with value: 0.3900209439867778 and parameters: {'vect_max_df': 0.7644239911797637, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'xgb_n_estimators':
. Best is trial 143 with value: 0.42008419094259714.
# [I 2025-05-07 17:07:05,918] Trial 218 finished with value: 0.3790471005244004 and parameters: {'vect_max_df': 0.9193833830851331, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'xgb_n_estimators': 319, 'xgb_max_depth': 11, 'xgb_learning_rate': 0.07678221148144375, 'xgb_subsample': 0.5038191972833818, 'xgb_colsample_bytree': 0.8681662596034907, 'xgb_reg_alpha': 0.006839070573615226, 'xgb_reg_lambda': 0.005725975212804499}. Best is trial 143 with value: 0.42008419094259714.
# [I 2025-05-07 17:07:24,702] Trial 219 finished with value: 0.39296798398297783 and parameters: {'vect_max_df': 0.8778994899082916, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'xgb_n_estimators': 338, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.10274869897543244, 'xgb_subsample': 0.5005516040839071, 'xgb_colsample_bytree': 0.7814481039697806, 'xgb_reg_alpha': 0.0021599934554430733, 'xgb_reg_lambda': 1.8549055773664363e-07}. Best is trial 143 with value: 0.42008419094259714.
# [I 2025-05-07 17:07:52,634] Trial 220 finished with value: 0.40434046441022425 and parameters: {'vect_max_df': 0.8950159416010279, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'xgb_n_estimators': 302, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.06161770606029233, 'xgb_subsample': 0.5369371098663077, 'xgb_colsample_bytree': 0.8256601901187232, 'xgb_reg_alpha': 0.0013410952711721302, 'xgb_reg_lambda': 0.019451145879860094}. Best is trial 143 with value: 0.42008419094259714.

# %%
group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
cv_results = cross_validate(xgb_model, X_train, y_train_enc, cv=cv, scoring=scoring, n_jobs=N_JOBS)

xgb_model.fit(X_train, y_train_enc)

acc = np.mean(cv_results['test_accuracy'])
pre = np.mean(cv_results['test_precision_macro'])
rec = np.mean(cv_results['test_recall_macro'])
f1_ = np.mean(cv_results['test_f1_macro'])

xgb_best_trial = xgb_study.best_trial
print("Best trial Cross-Validation results on the training set for XGBoost:")
print(f"  Accuracy:  {acc:.4f}")
print(f"  Precision: {pre:.4f}")
print(f"  Recall:    {rec:.4f}")
print(f"  F1:        {f1_:.4f}")

print("Best hyperparameters:")
for key, value in xgb_best_trial.params.items():
    print(f"  {key}: {value}")

model_filename = 'objects/task_2/models/best_xgb_{}_{}.pkl'.format(
    file_name,
    data_config
)
joblib.dump(xgb_model, model_filename)
print(f"XGBoost model saved as {model_filename}.")

task_val   = "task_2"
model_name = "XGBoost"
eval_type  = "inner"

save_eval_results(DB_PATH, db_file_name, task_val, model_name, eval_type, acc, pre, rec, f1_, xgb_study_name, json.dumps(xgb_study.best_params),language)
# Out:
# c:\Users\sebas\Escritorio\Python_env\NLP\lib\site-packages\xgboost\training.py:183: UserWarning: [18:00:34] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best trial Cross-Validation results on the training set for XGBoost:
#   Accuracy:  0.4670
#   Precision: 0.4814
#   Recall:    0.4756
#   F1:        0.4201
# Best hyperparameters:
#   vect_max_df: 0.7101803218606985
#   vect_min_df: 2
#   vect_ngram_range: 1,1
#   tfidf_use_idf: True
#   xgb_n_estimators: 316
#   xgb_max_depth: 3
#   xgb_learning_rate: 0.11772720195035212
#   xgb_subsample: 0.5762724384077174
#   xgb_colsample_bytree: 0.9433095569536869
#   xgb_reg_alpha: 0.0008035258701272992
#   xgb_reg_lambda: 1.2637214986667974e-07
# XGBoost model saved as objects/task_2/models/best_xgb_subtask2_all_aug_lang_spa_model_ml_stem_False_lem_True_dup_False_cased_False.pkl.
#
# Inserted CV results into 'eval' table in tfm.db.

# %% [markdown]
# ### Logistic Regression

# %%
lr_pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', LogisticRegression())  
])
group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
def lr_objective(trial):
    cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
    max_df = trial.suggest_float('vect_max_df', 0.5, 1.0)
    min_df = trial.suggest_int('vect_min_df', 1, 5)
    ngram_range_str = trial.suggest_categorical('vect_ngram_range', ["1,1", "1,2"])
    ngram_range = tuple(map(int, ngram_range_str.split(',')))
    
    use_idf = trial.suggest_categorical('tfidf_use_idf', [True, False])
    
    C = trial.suggest_float('lr_C', 1e-4, 10, log=True)
    penalty = trial.suggest_categorical('lr_penalty', ['l2', 'l1', 'elasticnet', 'none'])
    
    if penalty == 'none':
        penalty_value = None
    else:
        penalty_value = penalty
    
    solver = trial.suggest_categorical('lr_solver', ['lbfgs', 'sag', 'saga'])
    
    if penalty in ['l1', 'elasticnet'] and solver != 'saga':
        raise optuna.TrialPruned("Solver must be 'saga' for l1 or elasticnet penalty.")
    
    params = {
        'vect__max_df': max_df,
        'vect__min_df': min_df,
        'vect__ngram_range': ngram_range,
        'tfidf__use_idf': use_idf,
        'clf__C': C,
        'clf__penalty': penalty_value,
        'clf__solver': solver,
        'clf__class_weight': 'balanced',
        'clf__multi_class': 'multinomial', 
        'clf__random_state': SEED,
        'clf__max_iter': 2000
    }
    
    if penalty == 'elasticnet':
        l1_ratio = trial.suggest_float('lr_l1_ratio', 0.0, 1.0)
        params['clf__l1_ratio'] = l1_ratio
        
    lr_pipe = lr_pipeline.set_params(**params)
    scores = cross_val_score(lr_pipe, X_train, y_train_enc, cv=cv, scoring='f1_macro', n_jobs=N_JOBS)
    return np.mean(scores)

lr_study_name = 'lr_optimization_{}_{}'.format(file_name, data_config)
storage_name = f"sqlite:///objects/task_2/studies/{lr_study_name}.db"
lr_study = optuna.create_study(
    study_name=lr_study_name,
    storage=storage_name,
    direction="maximize",
    load_if_exists=True,
    sampler=optuna.samplers.TPESampler(seed=SEED)
)

budget = 500
lr_study.optimize(lr_objective, n_trials=budget)

def expand_lr_params(optuna_params, seed):
    expanded = {
        'vect__max_df': optuna_params['vect_max_df'],
        'vect__min_df': optuna_params['vect_min_df'],
        'vect__ngram_range': tuple(map(int, optuna_params['vect_ngram_range'].split(','))),
        'tfidf__use_idf': optuna_params['tfidf_use_idf'],
        'clf__C': optuna_params['lr_C'],
        'clf__penalty': None if optuna_params['lr_penalty'] == 'none' else optuna_params['lr_penalty'],
        'clf__solver': optuna_params['lr_solver'],
        'clf__class_weight': 'balanced',
        'clf__multi_class': 'multinomial',
        'clf__random_state': seed,
        'clf__max_iter': 2000
    }
    if optuna_params['lr_penalty'] == 'elasticnet':
        expanded['clf__l1_ratio'] = optuna_params['lr_l1_ratio']
    return expanded

best_params_expanded = expand_lr_params(lr_study.best_params, SEED)
lr_model = lr_pipeline.set_params(**best_params_expanded)

# %%
group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
cv_results = cross_validate(lr_model, X_train, y_train_enc, cv=cv, scoring=scoring, n_jobs=N_JOBS)

lr_model.fit(X_train, y_train_enc)

acc = np.mean(cv_results['test_accuracy'])
pre = np.mean(cv_results['test_precision_macro'])
rec = np.mean(cv_results['test_recall_macro'])
f1_ = np.mean(cv_results['test_f1_macro'])

lr_best_trial = lr_study.best_trial
print("Best trial Cross-Validation results on the training set for Logistic Regression:")
print(f"  Accuracy:  {acc:.4f}")
print(f"  Precision: {pre:.4f}")
print(f"  Recall:    {rec:.4f}")
print(f"  F1:        {f1_:.4f}")

print("Best hyperparameters:")
for key, value in lr_best_trial.params.items():
    print(f"  {key}: {value}")

model_filename = 'objects/task_2/models/best_lr_{}_{}.pkl'.format(
    file_name,
    data_config
)
joblib.dump(lr_model, model_filename)
print(f"Logistic Regression model saved as {model_filename}.")

task_val   = "task_2"
model_name = "Logistic Regression"
eval_type  = "inner"

save_eval_results(DB_PATH, db_file_name, task_val, model_name, eval_type, acc, pre, rec, f1_, lr_study_name, json.dumps(lr_study.best_params),language)
# Out:
# Best trial Cross-Validation results on the training set for Logistic Regression:
#   Accuracy:  0.4530
#   Precision: 0.4884
#   Recall:    0.4629
#   F1:        0.4552
# Best hyperparameters:
#   vect_max_df: 0.5076150727965348
#   vect_min_df: 1
#   vect_ngram_range: 1,1
#   tfidf_use_idf: True
#   lr_C: 0.0002877848038137215
#   lr_penalty: l2
#   lr_solver: lbfgs
# Logistic Regression model saved as objects/task_2/models/best_lr_subtask2_all_aug_lang_spa_model_ml_stem_False_lem_True_dup_False_cased_False.pkl.
#
# Inserted CV results into 'eval' table in tfm.db.
# c:\Users\sebas\Escritorio\Python_env\NLP\lib\site-packages\sklearn\linear_model\_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# c:\Users\sebas\Escritorio\Python_env\NLP\lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(

# %% [markdown]
# ## External Evaluation (held-out test set)

# %% [markdown]
# ### Random Forest

# %%
# Outer evaluation for Random Forest
y_pred_rf = rf_model.predict(X_test)
acc_rf = accuracy_score(y_test_enc, y_pred_rf)
pre_rf = precision_score(y_test_enc, y_pred_rf, average='macro')
rec_rf = recall_score(y_test_enc, y_pred_rf, average='macro')
f1_rf = f1_score(y_test_enc, y_pred_rf, average='macro')

print("\nOuter evaluation results for Random Forest:")
print(f"  Accuracy:  {acc_rf:.4f}")
print(f"  Precision: {pre_rf:.4f}")
print(f"  Recall:    {rec_rf:.4f}")
print(f"  F1:        {f1_rf:.4f}")

save_eval_results(DB_PATH, db_file_name, 
                  task_val="task_2", 
                  model_name="Random Forest", 
                  eval_type="outer", 
                  acc=acc_rf, pre=pre_rf, rec=rec_rf, f1_=f1_rf, 
                  study_name=rf_study_name, 
                  params=json.dumps(rf_study.best_params),
                  lang=language)
# Out:
# Outer evaluation results for Random Forest:
#   Accuracy:  0.5897
#   Precision: 0.4165
#   Recall:    0.3963
#   F1:        0.3917
#
# Inserted CV results into 'eval' table in tfm.db.

# %% [markdown]
# ### SVM

# %%
# Outer evaluation for SVM
y_pred_svm = svm_model.predict(X_test)
acc_svm = accuracy_score(y_test_enc, y_pred_svm)
pre_svm = precision_score(y_test_enc, y_pred_svm, average='macro')
rec_svm = recall_score(y_test_enc, y_pred_svm, average='macro')
f1_svm = f1_score(y_test_enc, y_pred_svm, average='macro')

print("\nOuter evaluation results for SVM:")
print(f"  Accuracy:  {acc_svm:.4f}")
print(f"  Precision: {pre_svm:.4f}")
print(f"  Recall:    {rec_svm:.4f}")
print(f"  F1:        {f1_svm:.4f}")

save_eval_results(DB_PATH, db_file_name, 
                  task_val="task_2", 
                  model_name="SVM", 
                  eval_type="outer", 
                  acc=acc_svm, pre=pre_svm, rec=rec_svm, f1_=f1_svm, 
                  study_name=svm_study_name, 
                  params=json.dumps(svm_study.best_params),
                  lang=language)
# Out:
# Outer evaluation results for SVM:
#   Accuracy:  0.5897
#   Precision: 0.4166
#   Recall:    0.4368
#   F1:        0.4230
#
# Inserted CV results into 'eval' table in tfm.db.

# %% [markdown]
# ### XGBoost

# %%
# Outer evaluation for XGBoost
y_pred_xgb = xgb_model.predict(X_test)
acc_xgb = accuracy_score(y_test_enc, y_pred_xgb)
pre_xgb = precision_score(y_test_enc, y_pred_xgb, average='macro')
rec_xgb = recall_score(y_test_enc, y_pred_xgb, average='macro')
f1_xgb = f1_score(y_test_enc, y_pred_xgb, average='macro')

print("\nOuter evaluation results for XGBoost:")
print(f"  Accuracy:  {acc_xgb:.4f}")
print(f"  Precision: {pre_xgb:.4f}")
print(f"  Recall:    {rec_xgb:.4f}")
print(f"  F1:        {f1_xgb:.4f}")

save_eval_results(DB_PATH, db_file_name, 
                  task_val="task_2", 
                  model_name="XGBoost", 
                  eval_type="outer", 
                  acc=acc_xgb, pre=pre_xgb, rec=rec_xgb, f1_=f1_xgb, 
                  study_name=xgb_study_name, 
                  params=json.dumps(xgb_study.best_params),
                  lang=language)
# Out:
# Outer evaluation results for XGBoost:
#   Accuracy:  0.6410
#   Precision: 0.4300
#   Recall:    0.4191
#   F1:        0.4178
#
# Inserted CV results into 'eval' table in tfm.db.

# %% [markdown]
# ### Logistic Regression

# %%
# Outer evaluation for Logistic Regression
y_pred_lr = lr_model.predict(X_test)
acc_lr = accuracy_score(y_test_enc, y_pred_lr)
pre_lr = precision_score(y_test_enc, y_pred_lr, average='macro')
rec_lr = recall_score(y_test_enc, y_pred_lr, average='macro')
f1_lr = f1_score(y_test_enc, y_pred_lr, average='macro')

print("Outer evaluation results for Logistic Regression:")
print(f"  Accuracy:  {acc_lr:.4f}")
print(f"  Precision: {pre_lr:.4f}")
print(f"  Recall:    {rec_lr:.4f}")
print(f"  F1:        {f1_lr:.4f}")

save_eval_results(DB_PATH, db_file_name, 
                  task_val="task_2", 
                  model_name="Logistic Regression", 
                  eval_type="outer", 
                  acc=acc_lr, pre=pre_lr, rec=rec_lr, f1_=f1_lr, 
                  study_name=lr_study_name, 
                  params=json.dumps(lr_study.best_params),
                  lang=language)
# Out:
# Outer evaluation results for Logistic Regression:
#   Accuracy:  0.4829
#   Precision: 0.4545
#   Recall:    0.4513
#   F1:        0.4045
#
# Inserted CV results into 'eval' table in tfm.db.
