# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import optuna
import joblib
import multiprocessing
import json

from sklearn.model_selection import cross_validate, cross_val_score, StratifiedGroupKFold, GroupShuffleSplit
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from collections import Counter
from utils import save_eval_results

J_JOBS = multiprocessing.cpu_count() - 1
SEED = 42
DB_PATH = "data/tfm.db" 
SUBTASK1_PATH = 'new_data\subtask1'

# %%
language = 'spa'
model_type = 'ml'
stemming = False
lemmatization = True
remove_duplicates = False
cased = True # Keep cased for DL models

data_config = f"lang_{language}_model_{model_type}_stem_{stemming}_lem_{lemmatization}_dup_{remove_duplicates}_cased_{cased}"
file_name = 'subtask1_balanced_aug_v2'


# db_file_name = 'subtask1_train_clean_{}.csv'.format(data_config)
db_file_name = '{}_{}.csv'.format(os.path.join(SUBTASK1_PATH, file_name), data_config)

if os.path.exists(db_file_name):
    full_data = pd.read_csv(db_file_name, encoding='utf-8') # , index_col='id'
    full_data = full_data.sample(frac=1, random_state=SEED).reset_index(drop=True) # Shuffle the data
    full_data['lyrics_clean'] = full_data['lyrics_clean'].str.lower()
    print('File found: ')
    print(full_data.info())
else:
    print('File not found...')    


original_data = full_data[full_data['is_augmented'] != True].copy()
original_data = original_data.sample(frac=1, random_state=SEED).reset_index(drop=True)
full_data = full_data.sample(frac=1, random_state=SEED).reset_index(drop=True)

original_data.info()
# Out:
# File found:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5136 entries, 0 to 5135
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5136 non-null   object
#  1   lyrics             5136 non-null   object
#  2   label              5136 non-null   object
#  3   augmentation_type  5136 non-null   object
#  4   is_augmented       5136 non-null   bool
#  5   lyrics_clean       5136 non-null   object
# dtypes: bool(1), object(5)
# memory usage: 205.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2104 entries, 0 to 2103
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2104 non-null   object
#  1   lyrics             2104 non-null   object
#  2   label              2104 non-null   object
#  3   augmentation_type  2104 non-null   object
#  4   is_augmented       2104 non-null   bool
#  5   lyrics_clean       2104 non-null   object
# dtypes: bool(1), object(5)
# memory usage: 84.4+ KB

# %%
full_training = False

# Prepare features and labels
data = original_data[['lyrics_clean', 'id', 'label']].copy()
# y = original_data[['label', 'id']].copy()
groups = data['id']

if not full_training:
    # Group-aware train-test split (80/20)
    gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=SEED)
    train_idx, test_idx = next(gss.split(data['lyrics_clean'], data['label'], groups))

    train, test = data.iloc[train_idx], data.iloc[test_idx]
else:
    print('Full training!')
    train = original_data[['lyrics_clean', 'id', 'label']].copy()

# %%
train = pd.merge(train[['id']], full_data, on = "id", how = "inner").copy()
train = train.sample(frac=1, random_state=SEED).reset_index(drop=True)

# %%
X_train = train['lyrics_clean']
y_train = train['label']

if not full_training:
    X_test = test['lyrics_clean']
    y_test = test['label']
    groups_test = test['id']

groups_train = train['id']

# %%
# Encode labels
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
if not full_training:
    # check for leakage
    leaked_ids = set(groups_train).intersection(set(groups_test))
    print("Leaked IDs:", leaked_ids)  # Should be: set()
    y_test_enc = le.transform(y_test)

# Label mapping
LABELS = le.classes_
NUM_LABELS = len(LABELS)
label2idx = {label: idx for idx, label in enumerate(LABELS)}
idx2label = {idx: label for label, idx in label2idx.items()}


scoring = {
    'accuracy': 'accuracy',
    'precision_macro': 'precision_macro',
    'recall_macro': 'recall_macro',
    'f1_macro': 'f1_macro'
}
# Out:
# Leaked IDs: set()

# %% [markdown]
# ### Random Forest

# %%
rf_pipeline = Pipeline([
        ('vect', CountVectorizer()),
        ('tfidf', TfidfTransformer()),
        ('clf', RandomForestClassifier(n_jobs=J_JOBS))
])
group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)

# objective function for Optuna
def objective(trial):
    cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
    max_df = trial.suggest_float('vect_max_df', 0.5, 1.0)
    min_df = trial.suggest_int('vect_min_df', 1, 5)

    ngram_range_str = trial.suggest_categorical('vect_ngram_range', ["1,1", "1,2"])
    ngram_range = tuple(map(int, ngram_range_str.split(',')))

    
    use_idf = trial.suggest_categorical('tfidf_use_idf', [True, False])
    
    n_estimators = trial.suggest_int('rf_n_estimators', 100, 530)
    max_depth = trial.suggest_categorical('rf_max_depth', [None] + list(range(5, 70, 5)))
    min_samples_split = trial.suggest_int('rf_min_samples_split', 2, 15)
    min_samples_leaf = trial.suggest_int('rf_min_samples_leaf', 1, 10)
    max_features = trial.suggest_categorical('rf_max_features', ['sqrt', 'log2', None])
    criterion = trial.suggest_categorical('rf_criterion', ['gini', 'entropy', 'log_loss'])
    

    params = {
        'vect__max_df': max_df,
        'vect__min_df': min_df,
        'vect__ngram_range': ngram_range,
        'tfidf__use_idf': use_idf,
        'clf__n_estimators': n_estimators,
        'clf__max_depth': max_depth,
        'clf__min_samples_split': min_samples_split,
        'clf__min_samples_leaf': min_samples_leaf,
        'clf__max_features': max_features,
        'clf__criterion': criterion,
        'clf__class_weight': 'balanced',  
        'clf__random_state': SEED      
    }
                
    rf_pipe = rf_pipeline.set_params(**params)
    
    # Evaluate with F1-score as metric 
    scores = cross_val_score(
        rf_pipe,
        X_train,
        y_train_enc,
        cv=cv,
        scoring='f1_macro',
        n_jobs=J_JOBS
    )

    return np.mean(scores)

# Optuna study and optimize the objective function
budget = 300
rf_study_name = 'rf_optimization_{}_{}'.format(file_name, data_config) + '_full_training' if full_training else ''
storage_name = f"sqlite:///objects/task_1/studies/{rf_study_name}.db"

rf_study = optuna.create_study(
    study_name=rf_study_name,
    storage=storage_name,
    direction="maximize",
    load_if_exists=True,  
    sampler=optuna.samplers.TPESampler(seed=SEED)  
)

rf_study.optimize(objective, n_trials=budget)

def expand_rf_params(optuna_params, seed):
    return {
        'vect__max_df': optuna_params['vect_max_df'],
        'vect__min_df': optuna_params['vect_min_df'],
        'vect__ngram_range': tuple(map(int, optuna_params['vect_ngram_range'].split(','))),
        'tfidf__use_idf': optuna_params['tfidf_use_idf'],
        'clf__n_estimators': optuna_params['rf_n_estimators'],
        'clf__max_depth': optuna_params['rf_max_depth'],
        'clf__min_samples_split': optuna_params['rf_min_samples_split'],
        'clf__min_samples_leaf': optuna_params['rf_min_samples_leaf'],
        'clf__max_features': optuna_params['rf_max_features'],
        'clf__criterion': optuna_params['rf_criterion'],
        'clf__class_weight': 'balanced',
        'clf__random_state': seed
    }

best_params_expanded = expand_rf_params(rf_study.best_params, SEED)
rf_model = rf_pipeline.set_params(**best_params_expanded)
# Out:
# [I 2025-05-11 23:24:48,463] A new study created in RDB with name: rf_optimization_subtask1_balanced_aug_v2_lang_spa_model_ml_stem_False_lem_True_dup_False_cased_True_NEW_full_training
# [I 2025-05-11 23:28:26,500] Trial 0 finished with value: 0.735424118705003 and parameters: {'vect_max_df': 0.6982109220775343, 'vect_min_df': 3, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'rf_n_estimators': 240, 'rf_max_depth': 40, 'rf_min_samples_split': 13, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_criterion': 'log_loss'}. Best is trial 0 with value: 0.735424118705003.
# [I 2025-05-11 23:28:33,145] Trial 1 finished with value: 0.7348078416384867 and parameters: {'vect_max_df': 0.6756221701465204, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'rf_n_estimators': 287, 'rf_max_depth': 5, 'rf_min_samples_split': 11, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 0 with value: 0.735424118705003.
# [I 2025-05-11 23:31:43,089] Trial 2 finished with value: 0.7272734069784896 and parameters: {'vect_max_df': 0.8272622770172439, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'rf_n_estimators': 177, 'rf_max_depth': 15, 'rf_min_samples_split': 14, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_criterion': 'entropy'}. Best is trial 0 with value: 0.735424118705003.
# [I 2025-05-11 23:31:50,335] Trial 3 finished with value: 0.7641383601497747 and parameters: {'vect_max_df': 0.8963311195691388, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 530, 'rf_max_depth': None, 'rf_min_samples_split': 13, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 3 with value: 0.7641383601497747.
# [I 2025-05-11 23:36:35,939] Trial 4 finished with value: 0.7328331234585749 and parameters: {'vect_max_df': 0.9571670053780259, 'vect_min_df': 3, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'rf_n_estimators': 291, 'rf_max_depth': 30, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_criterion': 'gini'}. Best is trial 3 with value: 0.7641383601497747.
# [I 2025-05-11 23:38:59,142] Trial 5 finished with value: 0.7397761333528908 and parameters: {'vect_max_df': 0.582123624410508, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 449, 'rf_max_depth': 25, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_criterion': 'gini'}. Best is trial 3 with value: 0.7641383601497747.
# [I 2025-05-11 23:42:52,001] Trial 6 finished with value: 0.7387359539316793 and parameters: {'vect_max_df': 0.5803199556142445, 'vect_min_df': 4, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'rf_n_estimators': 371, 'rf_max_depth': 30, 'rf_min_samples_split': 14, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_criterion': 'log_loss'}. Best is trial 3 with value: 0.7641383601497747.
# [I 2025-05-11 23:42:55,444] Trial 7 finished with value: 0.7430993983579495 and parameters: {'vect_max_df': 0.9336270230167255, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 141, 'rf_max_depth': 45, 'rf_min_samples_split': 14, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2', 'rf_criterion': 'entropy'}. Best is trial 3 with value: 0.7641383601497747.
# [I 2025-05-11 23:43:03,792] Trial 8 finished with value: 0.7630008642173498 and parameters: {'vect_max_df': 0.8519267763006465, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 314, 'rf_max_depth': 40, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 3 with value: 0.7641383601497747.
# [I 2025-05-11 23:44:38,202] Trial 9 finished with value: 0.734750197112734 and parameters: {'vect_max_df': 0.8003162024132005, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 162, 'rf_max_depth': 25, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_criterion': 'entropy'}. Best is trial 3 with value: 0.7641383601497747.
# [I 2025-05-11 23:44:43,814] Trial 10 finished with value: 0.7616513085916402 and parameters: {'vect_max_df': 0.9964000855202184, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 526, 'rf_max_depth': None, 'rf_min_samples_split': 11, 'rf_min_samples_leaf': 10, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 3 with value: 0.7641383601497747.
# [I 2025-05-11 23:44:47,016] Trial 11 finished with value: 0.7571073411341915 and parameters: {'vect_max_df': 0.8687356700483927, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 387, 'rf_max_depth': 10, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 3 with value: 0.7641383601497747.
# [I 2025-05-11 23:44:53,080] Trial 12 finished with value: 0.7648325058291718 and parameters: {'vect_max_df': 0.8794001236267075, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 528, 'rf_max_depth': 35, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 12 with value: 0.7648325058291718.
# [I 2025-05-11 23:44:59,698] Trial 13 finished with value: 0.764319190568399 and parameters: {'vect_max_df': 0.9057271040296682, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 528, 'rf_max_depth': 35, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 12 with value: 0.7648325058291718.
# [I 2025-05-11 23:45:02,850] Trial 14 finished with value: 0.7433272674146927 and parameters: {'vect_max_df': 0.7533132184298116, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 467, 'rf_max_depth': 35, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_criterion': 'gini'}. Best is trial 12 with value: 0.7648325058291718.
# [I 2025-05-11 23:45:09,259] Trial 15 finished with value: 0.758868405746407 and parameters: {'vect_max_df': 0.9209753449320672, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 435, 'rf_max_depth': 35, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 12 with value: 0.7648325058291718.
# [I 2025-05-11 23:45:14,147] Trial 16 finished with value: 0.7592209039513041 and parameters: {'vect_max_df': 0.7703488536498782, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 489, 'rf_max_depth': 20, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 12 with value: 0.7648325058291718.
# [I 2025-05-11 23:45:19,159] Trial 17 finished with value: 0.763927138989348 and parameters: {'vect_max_df': 0.9880246897367524, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 388, 'rf_max_depth': 50, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 12 with value: 0.7648325058291718.
# [I 2025-05-11 23:45:21,692] Trial 18 finished with value: 0.7522093228295013 and parameters: {'vect_max_df': 0.6856917972154041, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 413, 'rf_max_depth': 35, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_criterion': 'gini'}. Best is trial 12 with value: 0.7648325058291718.
# [I 2025-05-11 23:45:29,187] Trial 19 finished with value: 0.7611616988866488 and parameters: {'vect_max_df': 0.882675857384849, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 502, 'rf_max_depth': 35, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 12 with value: 0.7648325058291718.
# [I 2025-05-11 23:45:33,564] Trial 20 finished with value: 0.764864861477889 and parameters: {'vect_max_df': 0.5287988621851234, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 350, 'rf_max_depth': 35, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:45:37,889] Trial 21 finished with value: 0.7619225458029812 and parameters: {'vect_max_df': 0.5432682961592512, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 362, 'rf_max_depth': 35, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:45:41,534] Trial 22 finished with value: 0.7574026984300025 and parameters: {'vect_max_df': 0.6339065197227975, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 228, 'rf_max_depth': 35, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:45:46,384] Trial 23 finished with value: 0.7637912659742356 and parameters: {'vect_max_df': 0.5130445703593158, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 485, 'rf_max_depth': 35, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 9, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:45:50,485] Trial 24 finished with value: 0.7609816121145798 and parameters: {'vect_max_df': 0.8149651829284219, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 340, 'rf_max_depth': 20, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:45:52,990] Trial 25 finished with value: 0.7479420441877214 and parameters: {'vect_max_df': 0.721776093393617, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 419, 'rf_max_depth': 15, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 7, 'rf_max_features': 'log2', 'rf_criterion': 'gini'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:45:56,745] Trial 26 finished with value: 0.7435689686818964 and parameters: {'vect_max_df': 0.6378518652045613, 'vect_min_df': 3, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'rf_n_estimators': 468, 'rf_max_depth': 5, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 9, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:45:58,518] Trial 27 finished with value: 0.7527970876846736 and parameters: {'vect_max_df': 0.7839955594421875, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 112, 'rf_max_depth': 10, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:46:01,950] Trial 28 finished with value: 0.7628944080875767 and parameters: {'vect_max_df': 0.9130827461986484, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 218, 'rf_max_depth': 45, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:46:04,787] Trial 29 finished with value: 0.7447232776041076 and parameters: {'vect_max_df': 0.8435494171206871, 'vect_min_df': 5, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'rf_n_estimators': 253, 'rf_max_depth': 50, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 6, 'rf_max_features': 'log2', 'rf_criterion': 'log_loss'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:46:12,711] Trial 30 finished with value: 0.757554395680957 and parameters: {'vect_max_df': 0.9596193325896187, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 498, 'rf_max_depth': 40, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:46:19,005] Trial 31 finished with value: 0.7633554448359647 and parameters: {'vect_max_df': 0.8865809912191922, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 528, 'rf_max_depth': None, 'rf_min_samples_split': 15, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:46:24,839] Trial 32 finished with value: 0.7614212901848216 and parameters: {'vect_max_df': 0.8981403542724582, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 522, 'rf_max_depth': None, 'rf_min_samples_split': 11, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:46:30,562] Trial 33 finished with value: 0.7617431316545884 and parameters: {'vect_max_df': 0.9522427449375811, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 451, 'rf_max_depth': None, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:46:38,824] Trial 34 finished with value: 0.7551172671063094 and parameters: {'vect_max_df': 0.8356326561517948, 'vect_min_df': 4, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'rf_n_estimators': 500, 'rf_max_depth': 35, 'rf_min_samples_split': 12, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:47:18,078] Trial 35 finished with value: 0.7160594763154006 and parameters: {'vect_max_df': 0.7245093302773646, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 269, 'rf_max_depth': 5, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 7, 'rf_max_features': None, 'rf_criterion': 'entropy'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:47:23,093] Trial 36 finished with value: 0.7506146065013493 and parameters: {'vect_max_df': 0.6391984410976279, 'vect_min_df': 3, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'rf_n_estimators': 473, 'rf_max_depth': 15, 'rf_min_samples_split': 12, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:50:32,188] Trial 37 finished with value: 0.7347689984197405 and parameters: {'vect_max_df': 0.8628001402543239, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 435, 'rf_max_depth': 30, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_criterion': 'gini'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:50:38,712] Trial 38 finished with value: 0.7476747158762487 and parameters: {'vect_max_df': 0.9533879074705294, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'rf_n_estimators': 198, 'rf_max_depth': 35, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:50:43,236] Trial 39 finished with value: 0.7612972506695794 and parameters: {'vect_max_df': 0.5844706297190608, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 326, 'rf_max_depth': 25, 'rf_min_samples_split': 15, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:54:42,827] Trial 40 finished with value: 0.7389111870970468 and parameters: {'vect_max_df': 0.8137508896929784, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 515, 'rf_max_depth': None, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_criterion': 'entropy'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:54:46,977] Trial 41 finished with value: 0.7644245508101203 and parameters: {'vect_max_df': 0.9784236121648546, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 302, 'rf_max_depth': 50, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 20 with value: 0.764864861477889.
# [I 2025-05-11 23:54:51,024] Trial 42 finished with value: 0.7663075891078057 and parameters: {'vect_max_df': 0.9746081858463274, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 299, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-11 23:54:55,020] Trial 43 finished with value: 0.7660647649680096 and parameters: {'vect_max_df': 0.9709712986235084, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 292, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-11 23:54:59,127] Trial 44 finished with value: 0.765742953023615 and parameters: {'vect_max_df': 0.9801586393360809, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 293, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-11 23:55:02,474] Trial 45 finished with value: 0.7613429450920076 and parameters: {'vect_max_df': 0.9743961961034979, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 279, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-11 23:55:06,489] Trial 46 finished with value: 0.7612723242647763 and parameters: {'vect_max_df': 0.9334833577523657, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 345, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-11 23:55:08,670] Trial 47 finished with value: 0.7442682063395656 and parameters: {'vect_max_df': 0.9338001610949687, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 297, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'log2', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-11 23:55:11,782] Trial 48 finished with value: 0.7593397682840382 and parameters: {'vect_max_df': 0.9998374429056817, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 251, 'rf_max_depth': 50, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 9, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-11 23:55:15,488] Trial 49 finished with value: 0.7633696303509763 and parameters: {'vect_max_df': 0.9606199331603537, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 310, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:01:43,978] Trial 50 finished with value: 0.7385574719741925 and parameters: {'vect_max_df': 0.9285726880782453, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'rf_n_estimators': 272, 'rf_max_depth': 50, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 7, 'rf_max_features': None, 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:01:49,592] Trial 51 finished with value: 0.7662060555650576 and parameters: {'vect_max_df': 0.9890696400226601, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 296, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:01:56,465] Trial 52 finished with value: 0.7653544493579716 and parameters: {'vect_max_df': 0.9761696821397896, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 325, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:02:03,429] Trial 53 finished with value: 0.7643095120482457 and parameters: {'vect_max_df': 0.9765036015806305, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 333, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:02:09,024] Trial 54 finished with value: 0.763752512719504 and parameters: {'vect_max_df': 0.9963459473515852, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 357, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:02:14,858] Trial 55 finished with value: 0.7634681687471249 and parameters: {'vect_max_df': 0.9418237803297386, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 385, 'rf_max_depth': 50, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:02:21,157] Trial 56 finished with value: 0.760930333845967 and parameters: {'vect_max_df': 0.9730527401337582, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 321, 'rf_max_depth': 45, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:02:26,376] Trial 57 finished with value: 0.7594276581981713 and parameters: {'vect_max_df': 0.9173508016717044, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 288, 'rf_max_depth': 40, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:02:30,951] Trial 58 finished with value: 0.7636439232673475 and parameters: {'vect_max_df': 0.9861332767926536, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 255, 'rf_max_depth': 50, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:02:34,346] Trial 59 finished with value: 0.7381122031763121 and parameters: {'vect_max_df': 0.9675797110484027, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 373, 'rf_max_depth': 10, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 5, 'rf_max_features': 'log2', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:02:38,460] Trial 60 finished with value: 0.7643219044880168 and parameters: {'vect_max_df': 0.9480077679381685, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 312, 'rf_max_depth': 30, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:02:41,975] Trial 61 finished with value: 0.7626464877808103 and parameters: {'vect_max_df': 0.9046868291569659, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 349, 'rf_max_depth': 20, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:02:45,194] Trial 62 finished with value: 0.7593075956691913 and parameters: {'vect_max_df': 0.9985482770512304, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 237, 'rf_max_depth': 25, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:02:48,900] Trial 63 finished with value: 0.7651236821617509 and parameters: {'vect_max_df': 0.8738825933291035, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 292, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:02:52,510] Trial 64 finished with value: 0.7639117128379296 and parameters: {'vect_max_df': 0.865887647140123, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 289, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:02:56,255] Trial 65 finished with value: 0.7630486924789945 and parameters: {'vect_max_df': 0.9428070513783038, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 262, 'rf_max_depth': 50, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:03:00,005] Trial 66 finished with value: 0.7637324928765413 and parameters: {'vect_max_df': 0.6131645770243139, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 303, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:03:04,461] Trial 67 finished with value: 0.7633892140114243 and parameters: {'vect_max_df': 0.9844627281420568, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 322, 'rf_max_depth': 50, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:03:07,532] Trial 68 finished with value: 0.7588897055503165 and parameters: {'vect_max_df': 0.9212524028838254, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 283, 'rf_max_depth': 15, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:03:09,717] Trial 69 finished with value: 0.7297211335254963 and parameters: {'vect_max_df': 0.6676397500064918, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 335, 'rf_max_depth': 5, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:03:13,674] Trial 70 finished with value: 0.7604976474146007 and parameters: {'vect_max_df': 0.5517248559565602, 'vect_min_df': 4, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'rf_n_estimators': 206, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:03:17,077] Trial 71 finished with value: 0.7638412509406238 and parameters: {'vect_max_df': 0.786833447204815, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 244, 'rf_max_depth': 35, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:03:21,047] Trial 72 finished with value: 0.765180956559121 and parameters: {'vect_max_df': 0.8831460499370364, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 271, 'rf_max_depth': 35, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:03:25,396] Trial 73 finished with value: 0.7615005047136297 and parameters: {'vect_max_df': 0.8877780473410195, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 278, 'rf_max_depth': 45, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:03:29,748] Trial 74 finished with value: 0.764245072104873 and parameters: {'vect_max_df': 0.964439621751561, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 298, 'rf_max_depth': 35, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:03:32,278] Trial 75 finished with value: 0.7588559203992612 and parameters: {'vect_max_df': 0.7271263008289764, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 267, 'rf_max_depth': 10, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:05:37,567] Trial 76 finished with value: 0.7400455111360643 and parameters: {'vect_max_df': 0.9070764749183936, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 312, 'rf_max_depth': 40, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:05:41,517] Trial 77 finished with value: 0.7629061789705418 and parameters: {'vect_max_df': 0.9547995110987417, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 368, 'rf_max_depth': 20, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:05:45,359] Trial 78 finished with value: 0.7628313007395631 and parameters: {'vect_max_df': 0.7545078565414018, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 238, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:05:49,375] Trial 79 finished with value: 0.7631377970471063 and parameters: {'vect_max_df': 0.8539814946167474, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 328, 'rf_max_depth': 35, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:05:54,826] Trial 80 finished with value: 0.7648913434312077 and parameters: {'vect_max_df': 0.8249750415892324, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 354, 'rf_max_depth': 50, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:06:00,364] Trial 81 finished with value: 0.7654843879335866 and parameters: {'vect_max_df': 0.8272346336599322, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 343, 'rf_max_depth': 50, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:06:06,798] Trial 82 finished with value: 0.7567978479781994 and parameters: {'vect_max_df': 0.8255311506881271, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 341, 'rf_max_depth': 50, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:06:13,281] Trial 83 finished with value: 0.7627156791531029 and parameters: {'vect_max_df': 0.8010369646730631, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 398, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:06:19,886] Trial 84 finished with value: 0.7544106488041459 and parameters: {'vect_max_df': 0.8481093966431321, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 292, 'rf_max_depth': 50, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:06:26,094] Trial 85 finished with value: 0.7646583429275953 and parameters: {'vect_max_df': 0.8330938458036495, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 355, 'rf_max_depth': 50, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:06:33,764] Trial 86 finished with value: 0.7531498135046013 and parameters: {'vect_max_df': 0.877459343517039, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'rf_n_estimators': 306, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:06:38,264] Trial 87 finished with value: 0.7620540308855382 and parameters: {'vect_max_df': 0.8123653568084732, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 318, 'rf_max_depth': 30, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:09:22,053] Trial 88 finished with value: 0.7415653946000162 and parameters: {'vect_max_df': 0.8930088970555469, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 274, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:09:24,955] Trial 89 finished with value: 0.7471206380333608 and parameters: {'vect_max_df': 0.9870589472039217, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 329, 'rf_max_depth': 25, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:09:31,216] Trial 90 finished with value: 0.7524859447468183 and parameters: {'vect_max_df': 0.7764231797938866, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 261, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_criterion': 'gini'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:09:36,503] Trial 91 finished with value: 0.7623946347775441 and parameters: {'vect_max_df': 0.8740205709404797, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 371, 'rf_max_depth': 35, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:09:41,172] Trial 92 finished with value: 0.7643462917676376 and parameters: {'vect_max_df': 0.9318765167244168, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 349, 'rf_max_depth': 50, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:09:43,928] Trial 93 finished with value: 0.7485148714615015 and parameters: {'vect_max_df': 0.9663707595492954, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 382, 'rf_max_depth': 5, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:09:47,381] Trial 94 finished with value: 0.7573505361093164 and parameters: {'vect_max_df': 0.858870819313509, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 297, 'rf_max_depth': 15, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:09:55,235] Trial 95 finished with value: 0.7562341693443149 and parameters: {'vect_max_df': 0.8014053318050364, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 401, 'rf_max_depth': 50, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_criterion': 'log_loss'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:10:01,624] Trial 96 finished with value: 0.7652434490564584 and parameters: {'vect_max_df': 0.9455626884286307, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 362, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:10:08,177] Trial 97 finished with value: 0.7650447738030259 and parameters: {'vect_max_df': 0.9877246615692777, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 338, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:10:13,336] Trial 98 finished with value: 0.7650251918493313 and parameters: {'vect_max_df': 0.9423163204262748, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 336, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:10:19,320] Trial 99 finished with value: 0.7551191521513324 and parameters: {'vect_max_df': 0.9784560827422739, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'rf_n_estimators': 319, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:10:23,746] Trial 100 finished with value: 0.76270142370523 and parameters: {'vect_max_df': 0.9912346068564897, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 308, 'rf_max_depth': 50, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:10:28,426] Trial 101 finished with value: 0.7642420145059214 and parameters: {'vect_max_df': 0.9482326804467305, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 337, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:10:33,046] Trial 102 finished with value: 0.7654280202772614 and parameters: {'vect_max_df': 0.959260280162276, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 364, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:10:37,883] Trial 103 finished with value: 0.765469042161153 and parameters: {'vect_max_df': 0.9587415391200662, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 365, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:10:42,586] Trial 104 finished with value: 0.7652434490564584 and parameters: {'vect_max_df': 0.9233275036002513, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 362, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:10:47,145] Trial 105 finished with value: 0.7652272592881988 and parameters: {'vect_max_df': 0.9262385595720665, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 361, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 42 with value: 0.7663075891078057.
# [I 2025-05-12 00:10:52,091] Trial 106 finished with value: 0.7665458177034754 and parameters: {'vect_max_df': 0.923111182534485, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 398, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 106 with value: 0.7665458177034754.
# [I 2025-05-12 00:10:54,414] Trial 107 finished with value: 0.7452915901925862 and parameters: {'vect_max_df': 0.9691545056901575, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 378, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'log2', 'rf_criterion': 'entropy'}. Best is trial 106 with value: 0.7665458177034754.
# [I 2025-05-12 00:10:59,364] Trial 108 finished with value: 0.7661887790144449 and parameters: {'vect_max_df': 0.9580587117649412, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 397, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 106 with value: 0.7665458177034754.
# [I 2025-05-12 00:14:20,198] Trial 109 finished with value: 0.7396130460735775 and parameters: {'vect_max_df': 0.9580279997600057, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 420, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_criterion': 'entropy'}. Best is trial 106 with value: 0.7665458177034754.
# [I 2025-05-12 00:14:25,665] Trial 110 finished with value: 0.7630776325517263 and parameters: {'vect_max_df': 0.9380191216250251, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 398, 'rf_max_depth': 45, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 106 with value: 0.7665458177034754.
# [I 2025-05-12 00:14:31,299] Trial 111 finished with value: 0.7659768228819381 and parameters: {'vect_max_df': 0.9780883647566734, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 411, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 106 with value: 0.7665458177034754.
# [I 2025-05-12 00:14:36,671] Trial 112 finished with value: 0.7653561030196488 and parameters: {'vect_max_df': 0.9775714084733133, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 432, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 106 with value: 0.7665458177034754.
# [I 2025-05-12 00:14:42,340] Trial 113 finished with value: 0.7655691938493824 and parameters: {'vect_max_df': 0.974095200086667, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 447, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 106 with value: 0.7665458177034754.
# [I 2025-05-12 00:14:47,935] Trial 114 finished with value: 0.7657601024559995 and parameters: {'vect_max_df': 0.9600058067138421, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 451, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 106 with value: 0.7665458177034754.
# [I 2025-05-12 00:14:53,394] Trial 115 finished with value: 0.7649866654600836 and parameters: {'vect_max_df': 0.9596006620002662, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 440, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 106 with value: 0.7665458177034754.
# [I 2025-05-12 00:14:56,604] Trial 116 finished with value: 0.7521933444210813 and parameters: {'vect_max_df': 0.9956378126738148, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 452, 'rf_max_depth': 10, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 106 with value: 0.7665458177034754.
# [I 2025-05-12 00:15:01,769] Trial 117 finished with value: 0.7639346308101211 and parameters: {'vect_max_df': 0.968870122015705, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 417, 'rf_max_depth': 40, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 106 with value: 0.7665458177034754.
# [I 2025-05-12 00:15:06,529] Trial 118 finished with value: 0.7637586576456824 and parameters: {'vect_max_df': 0.9548304000350565, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 409, 'rf_max_depth': 50, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 106 with value: 0.7665458177034754.
# [I 2025-05-12 00:15:10,201] Trial 119 finished with value: 0.7584230369304736 and parameters: {'vect_max_df': 0.999937155305374, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 391, 'rf_max_depth': 20, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 106 with value: 0.7665458177034754.
# ...
# [I 2025-05-12 00:44:28,535] Trial 261 finished with value: 0.7635175122135097 and parameters: {'vect_max_df': 0.6732998398191339, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 392, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:44:33,693] Trial 262 finished with value: 0.7672148905713658 and parameters: {'vect_max_df': 0.6806113617064984, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 390, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:44:38,603] Trial 263 finished with value: 0.7649654575908583 and parameters: {'vect_max_df': 0.6652608795883581, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 362, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:44:44,001] Trial 264 finished with value: 0.7627489387592878 and parameters: {'vect_max_df': 0.6415880198419096, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 388, 'rf_max_depth': None, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:44:49,672] Trial 265 finished with value: 0.7652692139958718 and parameters: {'vect_max_df': 0.6839746187549415, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 377, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:44:56,939] Trial 266 finished with value: 0.7563127372293785 and parameters: {'vect_max_df': 0.6238758934497718, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'rf_n_estimators': 367, 'rf_max_depth': None, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:45:02,007] Trial 267 finished with value: 0.7668709046789453 and parameters: {'vect_max_df': 0.6755788491244333, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 390, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:45:04,555] Trial 268 finished with value: 0.7399993837109966 and parameters: {'vect_max_df': 0.6723483003178189, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 389, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 7, 'rf_max_features': 'log2', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:45:09,391] Trial 269 finished with value: 0.7632699195823076 and parameters: {'vect_max_df': 0.6576115333196798, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 380, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:48:32,758] Trial 270 finished with value: 0.7401843261194403 and parameters: {'vect_max_df': 0.6804428681739175, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 388, 'rf_max_depth': None, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:48:37,743] Trial 271 finished with value: 0.7673838268493933 and parameters: {'vect_max_df': 0.6706159885569295, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 371, 'rf_max_depth': None, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:48:42,789] Trial 272 finished with value: 0.7641559820338812 and parameters: {'vect_max_df': 0.6624935183486729, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 355, 'rf_max_depth': None, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:48:48,085] Trial 273 finished with value: 0.7619847467074728 and parameters: {'vect_max_df': 0.669978198766782, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 370, 'rf_max_depth': None, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:48:53,250] Trial 274 finished with value: 0.7648731491274436 and parameters: {'vect_max_df': 0.6812952743805224, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 361, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:48:58,244] Trial 275 finished with value: 0.764010968743753 and parameters: {'vect_max_df': 0.6887877439827363, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 380, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:49:03,018] Trial 276 finished with value: 0.7634043245398174 and parameters: {'vect_max_df': 0.6525577856662047, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 372, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:49:07,103] Trial 277 finished with value: 0.7648363234634783 and parameters: {'vect_max_df': 0.6740966775248489, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 389, 'rf_max_depth': 25, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:49:11,611] Trial 278 finished with value: 0.7630673569419013 and parameters: {'vect_max_df': 0.6866111912820146, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 379, 'rf_max_depth': 30, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:49:15,718] Trial 279 finished with value: 0.7644901108005648 and parameters: {'vect_max_df': 0.6749098531982306, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 348, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:49:18,056] Trial 280 finished with value: 0.7515414687777477 and parameters: {'vect_max_df': 0.6980478015726606, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 365, 'rf_max_depth': 5, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:49:21,585] Trial 281 finished with value: 0.7552933205021688 and parameters: {'vect_max_df': 0.6819399277898015, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 393, 'rf_max_depth': 15, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:49:26,526] Trial 282 finished with value: 0.763201212303334 and parameters: {'vect_max_df': 0.6630744358693816, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 375, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:49:31,640] Trial 283 finished with value: 0.7633916318926957 and parameters: {'vect_max_df': 0.6503342252904092, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 386, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:49:36,586] Trial 284 finished with value: 0.764268848106999 and parameters: {'vect_max_df': 0.6922576502533538, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 381, 'rf_max_depth': 45, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:49:41,781] Trial 285 finished with value: 0.7669591112717642 and parameters: {'vect_max_df': 0.6677438841904751, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 392, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:49:49,494] Trial 286 finished with value: 0.7565567511789013 and parameters: {'vect_max_df': 0.6634027861575511, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'rf_n_estimators': 390, 'rf_max_depth': None, 'rf_min_samples_split': 15, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:49:54,346] Trial 287 finished with value: 0.7678802341416234 and parameters: {'vect_max_df': 0.6727898679086167, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 369, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:49:58,957] Trial 288 finished with value: 0.7651689525505105 and parameters: {'vect_max_df': 0.6339059776378692, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 358, 'rf_max_depth': None, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:50:03,804] Trial 289 finished with value: 0.7663870667553776 and parameters: {'vect_max_df': 0.6726822494595055, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 373, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:50:08,791] Trial 290 finished with value: 0.7673914617195038 and parameters: {'vect_max_df': 0.6814538038466647, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 369, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:50:13,614] Trial 291 finished with value: 0.7658259907865855 and parameters: {'vect_max_df': 0.6801133270143146, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 364, 'rf_max_depth': None, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:50:18,415] Trial 292 finished with value: 0.7639768441304653 and parameters: {'vect_max_df': 0.6556970657762043, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 356, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:50:20,804] Trial 293 finished with value: 0.7398331712455717 and parameters: {'vect_max_df': 0.6695022122906364, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 367, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 7, 'rf_max_features': 'log2', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:54:52,995] Trial 294 finished with value: 0.7422638363988696 and parameters: {'vect_max_df': 0.6902412004315567, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 373, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:54:58,914] Trial 295 finished with value: 0.7599402035982156 and parameters: {'vect_max_df': 0.7023891308329082, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'rf_n_estimators': 380, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:55:04,309] Trial 296 finished with value: 0.7647786127594947 and parameters: {'vect_max_df': 0.6439518382095182, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 352, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:55:09,185] Trial 297 finished with value: 0.7670115511787557 and parameters: {'vect_max_df': 0.6796311429209333, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 368, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:55:14,259] Trial 298 finished with value: 0.7656308291949108 and parameters: {'vect_max_df': 0.6814645760028848, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 366, 'rf_max_depth': None, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.
# [I 2025-05-12 00:55:19,278] Trial 299 finished with value: 0.7643621155734973 and parameters: {'vect_max_df': 0.6620247250522951, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'rf_n_estimators': 345, 'rf_max_depth': None, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_criterion': 'entropy'}. Best is trial 236 with value: 0.7683940448934969.

# %%
if not full_training:
    group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
    cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
    cv_results = cross_validate(rf_model, X_train, y_train_enc, cv=cv, scoring=scoring, n_jobs=J_JOBS)

    # Refit the best model on the full training data
    rf_model.fit(X_train, y_train_enc)

    # Calculate mean metrics
    acc = np.mean(cv_results['test_accuracy'])
    pre = np.mean(cv_results['test_precision_macro'])
    rec = np.mean(cv_results['test_recall_macro'])
    f1_ = np.mean(cv_results['test_f1_macro'])

    # Best trial details
    rf_best_trial = rf_study.best_trial
    print("Best trial Cross-Validation results on the training set for Random Forest:")
    print(f"  Accuracy:  {acc:.4f}")
    print(f"  Precision: {pre:.4f}")
    print(f"  Recall:    {rec:.4f}")
    print(f"  F1:        {f1_:.4f}")

    print("Best hyperparameters:")
    for key, value in rf_best_trial.params.items():
        print(f"  {key}: {value}")

    # Save the best RF model
    model_filename = 'objects/task_1/models/best_rf_{}_{}.pkl'.format(file_name, data_config)
    joblib.dump(rf_model, model_filename)
    print(f"Random Forest model saved as {model_filename}.")

    # Insert results into the 'eval' table in tfm.db (assuming you have a function called save_eval_results)
    task_val   = "task_1"
    model_name = "Random Forest"
    eval_type  = "inner"  

    save_eval_results(DB_PATH, db_file_name, task_val, model_name, eval_type, acc, pre, rec, f1_, rf_study_name, json.dumps(rf_study.best_params), language)

else: 
    # Refit the best model on the full competition training data
    rf_model.fit(full_data['lyrics_clean'], y_train_enc)
    
    # Best trial details
    rf_best_trial = rf_study.best_trial

    print("Best hyperparameters:")
    for key, value in rf_best_trial.params.items():
        print(f"  {key}: {value}")

    # Save the best RF model
    full_data_config =  data_config + '_full_training' if full_training else ''
    model_filename = 'objects/task_1/models/best_rf_{}_{}.pkl'.format(file_name, full_data_config)
    joblib.dump(rf_model, model_filename)
    print(f"Random Forest model saved as {model_filename}.")
# Out:
# Best hyperparameters:
#   vect_max_df: 0.6825285544981433
#   vect_min_df: 2
#   vect_ngram_range: 1,1
#   tfidf_use_idf: True
#   rf_n_estimators: 371
#   rf_max_depth: 50
#   rf_min_samples_split: 2
#   rf_min_samples_leaf: 6
#   rf_max_features: sqrt
#   rf_criterion: entropy
# Random Forest model saved as objects/task_1/models/best_rf_subtask1_balanced_aug_v2_lang_spa_model_ml_stem_False_lem_True_dup_False_cased_True_NEW_full_training.pkl.

# %% [markdown]
# ### SVM

# %%
svm_pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', SVC())
])

def svm_objective(trial):
    group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
    cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
    max_df = trial.suggest_float('vect_max_df', 0.5, 1.0)
    min_df = trial.suggest_int('vect_min_df', 1, 5)
    
    ngram_range_str = trial.suggest_categorical('vect_ngram_range', ["1,1", "1,2"])
    ngram_range = tuple(map(int, ngram_range_str.split(',')))
    
    use_idf = trial.suggest_categorical('tfidf_use_idf', [True, False])
    norm = trial.suggest_categorical('tfidf_norm', ['l1', 'l2', None]) 
    
    C = trial.suggest_float('svm_C', 1e-3, 10, log=True)
    kernel = trial.suggest_categorical('svm_kernel', ['linear', 'rbf', 'sigmoid', 'poly'])
    shrinking = trial.suggest_categorical('svm_shrinking', [True, False]) 
    
    params = {
        'vect__max_df': max_df,
        'vect__min_df': min_df,
        'vect__ngram_range': ngram_range,
        'tfidf__use_idf': use_idf,
        'tfidf__norm': norm, 
        'clf__C': C,
        'clf__kernel': kernel,
        'clf__shrinking': shrinking, 
        # 'clf__class_weight': 'balanced',
        'clf__random_state': SEED  
    }
    
    # For non-linear kernels explore gamma
    if kernel != 'linear':
        gamma = trial.suggest_float('svm_gamma', 1e-4, 1, log=True)
        params['clf__gamma'] = gamma
    if kernel == 'poly':
        params['clf__degree'] = trial.suggest_int('svm_degree', 2, 5)
        params['clf__coef0'] = trial.suggest_float('svm_coef0', 0.0, 1.0)
    
    # Update pipeline with current hyperparameters
    svm_pipe = svm_pipeline.set_params(**params)
    
    # Evaluate with F1-score using cross-validation
    scores = cross_val_score(svm_pipe, X_train, y_train, cv=cv, scoring='f1_macro', n_jobs=J_JOBS)
    return scores.mean()

# Create an Optuna study for SVM. For a new study, ensure the study name is unique
svm_study_name = 'svm_optimization_{}_{}'.format(file_name,data_config)
storage_name = f"sqlite:///objects/task_1/studies/{svm_study_name}.db"

svm_study = optuna.create_study(
    study_name=svm_study_name,
    storage=storage_name,
    direction="maximize",
    load_if_exists=True,
    sampler=optuna.samplers.TPESampler(seed=SEED)
)

# Optimize the objective function
budget = 150
svm_study.optimize(svm_objective, n_trials=budget)

# Extract the best parameters and update the pipeline
best_params = svm_study.best_params

def expand_svm_params(optuna_params, seed):
    # Expand parameters from Optuna's best trial into full pipeline format
    expanded = {
        'vect__max_df': optuna_params['vect_max_df'],
        'vect__min_df': optuna_params['vect_min_df'],
        'vect__ngram_range': tuple(map(int, optuna_params['vect_ngram_range'].split(','))),
        'tfidf__use_idf': optuna_params['tfidf_use_idf'],
        'tfidf__norm': optuna_params['tfidf_norm'],
        'clf__C': optuna_params['svm_C'],
        'clf__kernel': optuna_params['svm_kernel'],
        'clf__shrinking': optuna_params['svm_shrinking'],
        # 'clf__class_weight': 'balanced',
        'clf__random_state': seed
    }

    if optuna_params['svm_kernel'] != 'linear':
        expanded['clf__gamma'] = optuna_params['svm_gamma']
    if optuna_params['svm_kernel'] == 'poly':
        expanded['clf__degree'] = optuna_params['svm_degree']
        expanded['clf__coef0'] = optuna_params['svm_coef0']

    return expanded

best_params_expanded = expand_svm_params(svm_study.best_params, SEED)
svm_model = svm_pipeline.set_params(**best_params_expanded)
# Out:
# [I 2025-03-31 14:16:37,842] Using an existing study with name 'svm_optimization_subtask1_balanced_aug_lang_spa_model_ml_stem_False_lem_True_dup_True_cased_False_v2' instead of creating a new one.
# [I 2025-03-31 14:16:44,362] Trial 70 finished with value: 0.7391784308148306 and parameters: {'vect_max_df': 0.8779230310052889, 'vect_min_df': 3, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 3.1855880538611396, 'svm_kernel': 'sigmoid', 'svm_shrinking': True, 'svm_gamma': 0.031051539889644413}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:16:48,871] Trial 71 finished with value: 0.7390781326415319 and parameters: {'vect_max_df': 0.8102638758125771, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': None, 'svm_C': 6.755238196248923, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:16:56,284] Trial 72 finished with value: 0.772671909356629 and parameters: {'vect_max_df': 0.9591836324523068, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 2.004419401690679, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:17:02,137] Trial 73 finished with value: 0.7738756927909648 and parameters: {'vect_max_df': 0.8224466104339259, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 2.864897836219154, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:17:08,142] Trial 74 finished with value: 0.7734609568539484 and parameters: {'vect_max_df': 0.815914117905969, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 3.2780350450907987, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:17:14,000] Trial 75 finished with value: 0.7726299059310732 and parameters: {'vect_max_df': 0.8607117170736439, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 5.580808744819938, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:17:19,884] Trial 76 finished with value: 0.7735281765545838 and parameters: {'vect_max_df': 0.7690472254594023, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.3301738286680125, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:17:25,551] Trial 77 finished with value: 0.7724082687807827 and parameters: {'vect_max_df': 0.761713917237753, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.6921018697221298, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:17:31,475] Trial 78 finished with value: 0.7734617191886171 and parameters: {'vect_max_df': 0.7288299848869989, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.631409085141204, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:17:37,351] Trial 79 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.6888846542373611, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l1', 'svm_C': 1.318430672997282, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:17:41,617] Trial 80 finished with value: 0.7585490803472513 and parameters: {'vect_max_df': 0.7296841985742581, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.3903445773409949, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:17:47,401] Trial 81 finished with value: 0.7557548628439609 and parameters: {'vect_max_df': 0.7740620209012267, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.22484196440040558, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:17:53,301] Trial 82 finished with value: 0.7734617191886171 and parameters: {'vect_max_df': 0.703906677592641, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.616669550022384, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:17:59,362] Trial 83 finished with value: 0.7738528621800153 and parameters: {'vect_max_df': 0.6526450043123173, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.7947067262527385, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:18:05,118] Trial 84 finished with value: 0.7723687318887784 and parameters: {'vect_max_df': 0.6615907189180218, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.1442253668181699, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:18:10,928] Trial 85 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.7279112015162409, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.6917120762830704, 'svm_kernel': 'rbf', 'svm_shrinking': True, 'svm_gamma': 0.011771328632654454}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:18:16,991] Trial 86 finished with value: 0.7747389538167159 and parameters: {'vect_max_df': 0.5898389781524161, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 2.4483364111918013, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:18:23,103] Trial 87 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.594327538366437, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'tfidf_norm': 'l2', 'svm_C': 0.921917266044022, 'svm_kernel': 'poly', 'svm_shrinking': True, 'svm_gamma': 0.0016511701444470595, 'svm_degree': 3, 'svm_coef0': 0.7155099424787212}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:18:26,736] Trial 88 finished with value: 0.7702004067344378 and parameters: {'vect_max_df': 0.6550676384989215, 'vect_min_df': 3, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.6056021096132105, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:18:32,331] Trial 89 finished with value: 0.7690554149122675 and parameters: {'vect_max_df': 0.5741666829505365, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 2.256844971035056, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:18:34,135] Trial 90 finished with value: 0.7382131264384801 and parameters: {'vect_max_df': 0.5194345438361587, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': None, 'svm_C': 1.5291258077291214, 'svm_kernel': 'sigmoid', 'svm_shrinking': True, 'svm_gamma': 0.00600466835587786}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:18:40,161] Trial 91 finished with value: 0.7726290914871241 and parameters: {'vect_max_df': 0.7042839761928849, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 2.600715097556798, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:18:46,540] Trial 92 finished with value: 0.7746978594704549 and parameters: {'vect_max_df': 0.6155047469145527, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.9283206611464854, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:18:52,754] Trial 93 finished with value: 0.7746978594704549 and parameters: {'vect_max_df': 0.6082520625863634, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 2.0214083512086716, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:18:58,821] Trial 94 finished with value: 0.774274984119248 and parameters: {'vect_max_df': 0.6141430317023678, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.8451649366718457, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:19:04,622] Trial 95 finished with value: 0.7709239431929058 and parameters: {'vect_max_df': 0.620202797971184, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.3665872489276732, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:19:10,521] Trial 96 finished with value: 0.7735828565864952 and parameters: {'vect_max_df': 0.6397097409203089, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.0186467438559161, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:19:16,421] Trial 97 finished with value: 0.7736331187333478 and parameters: {'vect_max_df': 0.6005682086493883, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.0581186739203412, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:19:22,339] Trial 98 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.5980856531638188, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'tfidf_norm': 'l1', 'svm_C': 0.9812744932676742, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:19:28,241] Trial 99 finished with value: 0.774208493979884 and parameters: {'vect_max_df': 0.646223904783327, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.288409571586611, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:19:32,660] Trial 100 finished with value: 0.75572941652533 and parameters: {'vect_max_df': 0.5511682382172086, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.7754373309785632, 'svm_kernel': 'linear', 'svm_shrinking': True}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:19:38,291] Trial 101 finished with value: 0.7748073802000812 and parameters: {'vect_max_df': 0.6391360424109545, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5475852324703608, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 52 with value: 0.7751173376162185.
# [I 2025-03-31 14:19:44,020] Trial 102 finished with value: 0.7779005097000276 and parameters: {'vect_max_df': 0.641553079854712, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5742201340786142, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 102 with value: 0.7779005097000276.
# [I 2025-03-31 14:19:49,707] Trial 103 finished with value: 0.7779580222332745 and parameters: {'vect_max_df': 0.6048159723384784, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.7655361455782779, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 103 with value: 0.7779580222332745.
# [I 2025-03-31 14:19:55,340] Trial 104 finished with value: 0.777943656832653 and parameters: {'vect_max_df': 0.6364317937037987, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.593470051853656, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 103 with value: 0.7779580222332745.
# [I 2025-03-31 14:20:01,096] Trial 105 finished with value: 0.7790624757330956 and parameters: {'vect_max_df': 0.5820964867161027, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5581863486289246, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 105 with value: 0.7790624757330956.
# [I 2025-03-31 14:20:06,841] Trial 106 finished with value: 0.7791063122881863 and parameters: {'vect_max_df': 0.5802653950046313, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5777184431709289, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:20:12,640] Trial 107 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.5712224773841749, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.3380432249169907, 'svm_kernel': 'rbf', 'svm_shrinking': False, 'svm_gamma': 0.0004831884037883343}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:20:18,231] Trial 108 finished with value: 0.777443437355745 and parameters: {'vect_max_df': 0.6110450743883055, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5712038478568885, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:20:21,731] Trial 109 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.5842890768173199, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5119066458219721, 'svm_kernel': 'poly', 'svm_shrinking': False, 'svm_gamma': 0.3640183678916086, 'svm_degree': 5, 'svm_coef0': 0.2342508998676489}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:20:26,893] Trial 110 finished with value: 0.748637977435959 and parameters: {'vect_max_df': 0.6326070991100947, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': None, 'svm_C': 0.24740774120391243, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:20:32,551] Trial 111 finished with value: 0.7768664651430125 and parameters: {'vect_max_df': 0.5378302552003403, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5968203891926842, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:20:38,402] Trial 112 finished with value: 0.7764931590688958 and parameters: {'vect_max_df': 0.5424718050544077, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5809336887198411, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:20:44,531] Trial 113 finished with value: 0.7738195686041016 and parameters: {'vect_max_df': 0.5033871143298528, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.4415622386725277, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:20:50,531] Trial 114 finished with value: 0.7768454323747696 and parameters: {'vect_max_df': 0.5514595116846708, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5899998975173651, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:20:56,201] Trial 115 finished with value: 0.7768664651430125 and parameters: {'vect_max_df': 0.5482865252943269, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5977300373615985, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:21:01,936] Trial 116 finished with value: 0.7764931590688958 and parameters: {'vect_max_df': 0.5622632745728011, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5821348630381741, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:21:08,025] Trial 117 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.5690079226564114, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.15785967868194378, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.0001135282133044707}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:21:13,118] Trial 118 finished with value: 0.7731025086464247 and parameters: {'vect_max_df': 0.5438945498937002, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'tfidf_norm': 'l2', 'svm_C': 0.722492851877779, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:21:16,851] Trial 119 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.5270549068380426, 'vect_min_df': 5, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l1', 'svm_C': 0.3239893455190625, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:21:22,433] Trial 120 finished with value: 0.7764094695260433 and parameters: {'vect_max_df': 0.5608074278546087, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.6124219339348386, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:21:25,816] Trial 121 finished with value: 0.7662268188826576 and parameters: {'vect_max_df': 0.5577997926786196, 'vect_min_df': 4, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.7877462419120949, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:21:31,571] Trial 122 finished with value: 0.7768664651430125 and parameters: {'vect_max_df': 0.5329008260603479, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.6065093557685721, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:21:37,301] Trial 123 finished with value: 0.7758686241692259 and parameters: {'vect_max_df': 0.5363141881169184, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.6417259743714421, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:21:43,102] Trial 124 finished with value: 0.7773164053260742 and parameters: {'vect_max_df': 0.5607805158342319, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5881055398204116, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:21:49,119] Trial 125 finished with value: 0.7758039441877556 and parameters: {'vect_max_df': 0.5820442426036888, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.41652724766914473, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:21:54,887] Trial 126 finished with value: 0.7564767675573996 and parameters: {'vect_max_df': 0.5228610342196056, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.2494869431202435, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:22:00,783] Trial 127 finished with value: 0.7768664651430125 and parameters: {'vect_max_df': 0.5426058832885012, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5941440508673604, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:22:06,581] Trial 128 finished with value: 0.7617833225263767 and parameters: {'vect_max_df': 0.5072920033510113, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.2877792138559662, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:22:12,485] Trial 129 finished with value: 0.774820728731623 and parameters: {'vect_max_df': 0.5420331890956683, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.4763684142705547, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:22:15,460] Trial 130 finished with value: 0.7755814313361178 and parameters: {'vect_max_df': 0.515427012710896, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.8178204158449639, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:22:22,125] Trial 131 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.5460579953686865, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.38236714651926934, 'svm_kernel': 'rbf', 'svm_shrinking': False, 'svm_gamma': 0.003790448451910027}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:22:28,412] Trial 132 finished with value: 0.7759379431697979 and parameters: {'vect_max_df': 0.5608388420695148, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.6283555027311449, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:22:34,621] Trial 133 finished with value: 0.7751838897236268 and parameters: {'vect_max_df': 0.533436205007843, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.568542304302316, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:22:40,924] Trial 134 finished with value: 0.7764038676585364 and parameters: {'vect_max_df': 0.5737820278886351, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.7402285720508822, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:22:47,322] Trial 135 finished with value: 0.7731751780945839 and parameters: {'vect_max_df': 0.5543348039334548, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.4328103913987991, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:22:53,903] Trial 136 finished with value: 0.7455959300017729 and parameters: {'vect_max_df': 0.5821444358337448, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.19693921934775277, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:23:00,804] Trial 137 finished with value: 0.7746649487331367 and parameters: {'vect_max_df': 0.5308948660028836, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5288415095038069, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:23:07,243] Trial 138 finished with value: 0.7639214100184023 and parameters: {'vect_max_df': 0.5660149499326816, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.31969849514899007, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:23:13,871] Trial 139 finished with value: 0.3527721961412147 and parameters: {'vect_max_df': 0.6071661042002497, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': None, 'svm_C': 0.8539328008686945, 'svm_kernel': 'poly', 'svm_shrinking': False, 'svm_gamma': 0.5993112594665809, 'svm_degree': 3, 'svm_coef0': 0.6130667986473779}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:23:19,351] Trial 140 finished with value: 0.7718344219654674 and parameters: {'vect_max_df': 0.6658924610152414, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'tfidf_norm': 'l2', 'svm_C': 0.6598738424607431, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:23:26,095] Trial 141 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.5496530589917865, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.38155569455817034, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.021797078050278366}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:23:32,365] Trial 142 finished with value: 0.7764931590688958 and parameters: {'vect_max_df': 0.5394434821523121, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5848014719734324, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:23:38,531] Trial 143 finished with value: 0.7746649487331367 and parameters: {'vect_max_df': 0.5344828635923154, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5270432117456073, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:23:44,865] Trial 144 finished with value: 0.7774584553936191 and parameters: {'vect_max_df': 0.5125719615480425, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.7102082097277754, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14
 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:26:20,626] Trial 169 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.6039074464949027, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.01371933763349604, 'svm_kernel': 'poly', 'svm_shrinking': False, 'svm_gamma': 0.9765944613333669, 'svm_degree': 4, 'svm_coef0': 0.8782368424377963}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:26:27,753] Trial 170 finished with value: 0.7718830285592888 and parameters: {'vect_max_df': 0.5015945336274583, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.2844534913263441, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:26:34,065] Trial 171 finished with value: 0.7766461965150554 and parameters: {'vect_max_df': 0.6246696234029137, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.7092901014036835, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:26:40,543] Trial 172 finished with value: 0.776540131437585 and parameters: {'vect_max_df': 0.526964389979595, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.8492606499872878, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:26:46,983] Trial 173 finished with value: 0.7761473027533906 and parameters: {'vect_max_df': 0.5152034411980593, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.48775485015786807, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:26:53,182] Trial 174 finished with value: 0.774440843309703 and parameters: {'vect_max_df': 0.5299332804741449, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.0331216732664072, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:26:59,773] Trial 175 finished with value: 0.77660548540913 and parameters: {'vect_max_df': 0.5135716329259372, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.677079152167403, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:27:06,804] Trial 176 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.5947511677255874, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.045625424145748036, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:27:13,196] Trial 177 finished with value: 0.7770693595304934 and parameters: {'vect_max_df': 0.5825261091529194, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.4252137809037373, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:27:20,093] Trial 178 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.5895399347371839, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.4009431238537068, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.2680820421736412}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:27:26,404] Trial 179 finished with value: 0.7756375259438879 and parameters: {'vect_max_df': 0.577836457199604, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.798172090816305, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:27:33,028] Trial 180 finished with value: 0.7760461959771454 and parameters: {'vect_max_df': 0.5106038961395023, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5055891822286971, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:27:40,552] Trial 181 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.6149371475864965, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l1', 'svm_C': 1.1272286476621582, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:27:47,151] Trial 182 finished with value: 0.7755695945494286 and parameters: {'vect_max_df': 0.533851092957139, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.7065729030249658, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:27:53,460] Trial 183 finished with value: 0.7773766913289357 and parameters: {'vect_max_df': 0.522828108779055, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.8639389192200719, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:27:59,481] Trial 184 finished with value: 0.7760654961955187 and parameters: {'vect_max_df': 0.5020097306151151, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.8822422953344632, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:28:05,509] Trial 185 finished with value: 0.7751411440992207 and parameters: {'vect_max_df': 0.524590775155289, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.682404508480606, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:28:12,207] Trial 186 finished with value: 0.7719820903968458 and parameters: {'vect_max_df': 0.5208846774869436, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 1.3431365863563205, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:28:15,408] Trial 187 finished with value: 0.7770176763589836 and parameters: {'vect_max_df': 0.5878032634152992, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.9661316478561435, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:28:18,586] Trial 188 finished with value: 0.774892752140555 and parameters: {'vect_max_df': 0.5915026643757451, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.9432299907082041, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:28:21,891] Trial 189 finished with value: 0.7785407089047794 and parameters: {'vect_max_df': 0.606390625903538, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.443789558304393, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:28:25,343] Trial 190 finished with value: 0.7747208488493286 and parameters: {'vect_max_df': 0.6044066690708931, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.3520576990309879, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:28:28,338] Trial 191 finished with value: 0.7751994885518503 and parameters: {'vect_max_df': 0.5836136720242238, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.4705353589584438, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:28:31,602] Trial 192 finished with value: 0.7773473755547124 and parameters: {'vect_max_df': 0.6156484961253832, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.6685766233118986, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 106 with value: 0.7791063122881863.
# [I 2025-03-31 14:28:34,542] Trial 193 finished with value: 0.7813294598020878 and parameters: {'vect_max_df': 0.619430164505521, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5479424829877481, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:28:37,609] Trial 194 finished with value: 0.7804350102405874 and parameters: {'vect_max_df': 0.6121058759022348, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5169586773999386, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:28:40,615] Trial 195 finished with value: 0.7785366384965301 and parameters: {'vect_max_df': 0.6214923362794086, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.42959985952405066, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:28:43,887] Trial 196 finished with value: 0.7761173070885898 and parameters: {'vect_max_df': 0.6374095135149425, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.2929848760587022, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:28:46,960] Trial 197 finished with value: 0.7804314399827857 and parameters: {'vect_max_df': 0.6206696891084706, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5230306768346706, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:28:49,942] Trial 198 finished with value: 0.7809059426417418 and parameters: {'vect_max_df': 0.6154940032859914, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5417238568994837, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:28:52,653] Trial 199 finished with value: 0.7715063220852022 and parameters: {'vect_max_df': 0.617804631515348, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'tfidf_norm': 'l2', 'svm_C': 0.5442835233085872, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:28:56,753] Trial 200 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.6208069613541004, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': None, 'svm_C': 0.3774000617155282, 'svm_kernel': 'rbf', 'svm_shrinking': False, 'svm_gamma': 0.0970101681481993}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:28:59,735] Trial 201 finished with value: 0.780010801683112 and parameters: {'vect_max_df': 0.6290523688566866, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.5116825634734382, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:02,720] Trial 202 finished with value: 0.7775771407516883 and parameters: {'vect_max_df': 0.6453107601796022, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.46435235819662035, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:05,613] Trial 203 finished with value: 0.7792739716142983 and parameters: {'vect_max_df': 0.6278853098936498, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.48786832820926546, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:08,501] Trial 204 finished with value: 0.7742460483183441 and parameters: {'vect_max_df': 0.6521016077384885, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.32567505076113523, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:11,261] Trial 205 finished with value: 0.7785045157104277 and parameters: {'vect_max_df': 0.6298097265251128, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.4466855274513144, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:14,177] Trial 206 finished with value: 0.7781351218296063 and parameters: {'vect_max_df': 0.6344764604616685, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.43652199310416034, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:17,090] Trial 207 finished with value: 0.7780377331546628 and parameters: {'vect_max_df': 0.6338383029822718, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.41619431127454404, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:19,947] Trial 208 finished with value: 0.7775662067984176 and parameters: {'vect_max_df': 0.6308298445515589, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.4118850218042845, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:23,363] Trial 209 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.6321587659537312, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.27166444051027977, 'svm_kernel': 'poly', 'svm_shrinking': False, 'svm_gamma': 0.0002425914439384348, 'svm_degree': 2, 'svm_coef0': 0.20666287236159409}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:26,320] Trial 210 finished with value: 0.7758500666796276 and parameters: {'vect_max_df': 0.6717669252065971, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.3638115628794349, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:29,221] Trial 211 finished with value: 0.7780656655452256 and parameters: {'vect_max_df': 0.6439396942320308, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.4282641703309042, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:32,226] Trial 212 finished with value: 0.7780377331546628 and parameters: {'vect_max_df': 0.6415505285790618, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.4168735230384549, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:35,230] Trial 213 finished with value: 0.7785045157104277 and parameters: {'vect_max_df': 0.6467091030827636, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.44666012876758504, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:38,220] Trial 214 finished with value: 0.7784875934111628 and parameters: {'vect_max_df': 0.6442479363435647, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.4203715032674531, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:41,572] Trial 215 finished with value: 0.7734583318497064 and parameters: {'vect_max_df': 0.6436430981338533, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.3318120379746634, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:44,611] Trial 216 finished with value: 0.7780377331546628 and parameters: {'vect_max_df': 0.6622943062588834, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.4180328347413234, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:47,685] Trial 217 finished with value: 0.7731474035778501 and parameters: {'vect_max_df': 0.6585535167954272, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.23608268293458498, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:50,503] Trial 218 finished with value: 0.7775662067984176 and parameters: {'vect_max_df': 0.6251297972534112, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l2', 'svm_C': 0.4112158297488861, 'svm_kernel': 'linear', 'svm_shrinking': False}. Best is trial 193 with value: 0.7813294598020878.
# [I 2025-03-31 14:29:53,869] Trial 219 finished with value: 0.3166720044828279 and parameters: {'vect_max_df': 0.647938022877795, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'tfidf_norm': 'l1', 'svm_C': 0.4803393103748738, 'svm_kernel': 'sigmoid', 'svm_shrinking': False, 'svm_gamma': 0.050311364486422906}. Best is trial 193 with value: 0.7813294598020878.

# %%
group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
cv_results = cross_validate(svm_model, X_train, y_train_enc, cv=cv, scoring=scoring, n_jobs=J_JOBS)
# Refit the best model on the full training data
svm_model.fit(X_train, y_train)

# Calculate mean metrics
acc = np.mean(cv_results['test_accuracy'])
pre = np.mean(cv_results['test_precision_macro'])
rec = np.mean(cv_results['test_recall_macro'])
f1_ = np.mean(cv_results['test_f1_macro'])

svm_best_trial = svm_study.best_trial
print("Best trial Cross-Validation results on the training set for SVM:")
print(f"  Accuracy:  {acc:.4f}")
print(f"  Precision: {pre:.4f}")
print(f"  Recall:    {rec:.4f}")
print(f"  F1:        {f1_:.4f}")


print("Best hyperparameters:")
for key, value in svm_best_trial.params.items():
    print("  {}: {}".format(key, value))

# Save the best SVM model
model_filename = 'objects/task_1/models/best_svm_{}_{}.pkl'.format(file_name, data_config)
joblib.dump(svm_model, model_filename)
print("SVM model saved as {}.".format(model_filename))

task_val = "task_1"
model_name   = "SVM"
eval_type   = "inner"  

save_eval_results(DB_PATH, db_file_name,task_val, model_name, eval_type,  acc, pre, rec, f1_, svm_study_name, json.dumps(svm_study.best_params), language)
# Out:
# Best trial Cross-Validation results on the training set for SVM:
#   Accuracy:  0.7837
#   Precision: 0.7906
#   Recall:    0.7838
#   F1:        0.7813
# Best hyperparameters:
#   vect_max_df: 0.619430164505521
#   vect_min_df: 1
#   vect_ngram_range: 1,1
#   tfidf_use_idf: True
#   tfidf_norm: l2
#   svm_C: 0.5479424829877481
#   svm_kernel: linear
#   svm_shrinking: False
# SVM model saved as objects/task_1/models/best_svm_subtask1_balanced_aug_lang_spa_model_ml_stem_False_lem_True_dup_True_cased_False.pkl.
#
# Inserted CV results into 'eval' table in tfm.db.

# %% [markdown]
# ### XGBoost

# %%
# scale_pos_weight for XGBoost 
counter = Counter(y_train)
majority = max(counter.values())
minority = min(counter.values())
scale_pos_weight = majority / minority

# %%
xgb_pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', XGBClassifier(use_label_encoder=False, eval_metric='logloss'))
])

def xgb_objective(trial):
    group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
    cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
    max_df = trial.suggest_float('vect_max_df', 0.5, 1.0)
    min_df = trial.suggest_int('vect_min_df', 1, 5)
    ngram_range_str = trial.suggest_categorical('vect_ngram_range', ["1,1", "1,2"])
    ngram_range = tuple(map(int, ngram_range_str.split(',')))
    
    use_idf = trial.suggest_categorical('tfidf_use_idf', [True, False])
    
    n_estimators = trial.suggest_int('xgb_n_estimators', 50, 500)
    max_depth = trial.suggest_int('xgb_max_depth', 3, 15)
    learning_rate = trial.suggest_float('xgb_learning_rate', 0.001, 0.4, log=True)
    subsample = trial.suggest_float('xgb_subsample', 0.5, 1.0)
    colsample_bytree = trial.suggest_float('xgb_colsample_bytree', 0.5, 1.0)
    reg_alpha = trial.suggest_float('xgb_reg_alpha', 1e-8, 1.0, log=True)
    reg_lambda = trial.suggest_float('xgb_reg_lambda', 1e-8, 1.0, log=True)
    
    params = {
        'vect__max_df': max_df,
        'vect__min_df': min_df,
        'vect__ngram_range': ngram_range,
        'tfidf__use_idf': use_idf,
        'clf__n_estimators': n_estimators,
        'clf__max_depth': max_depth,
        'clf__learning_rate': learning_rate,
        'clf__subsample': subsample,
        'clf__colsample_bytree': colsample_bytree,
        'clf__reg_alpha': reg_alpha,
        'clf__reg_lambda': reg_lambda,
        'clf__scale_pos_weight': scale_pos_weight,  
        'clf__random_state': SEED
    }
    
    xgb_pipe = xgb_pipeline.set_params(**params)
    
    scores = cross_val_score(xgb_pipe, X_train, y_train_enc, cv=cv, scoring='f1_macro', n_jobs=J_JOBS)
    return scores.mean()

xgb_study_name = 'xgb_optimization_{}_{}'.format(file_name, data_config)
storage_name = f"sqlite:///objects/task_1/studies/{xgb_study_name}.db"
xgb_study = optuna.create_study(
    study_name=xgb_study_name,
    storage=storage_name,
    direction="maximize",
    load_if_exists=True,
    sampler=optuna.samplers.TPESampler(seed=SEED)
)

budget = 300
xgb_study.optimize(xgb_objective, n_trials=budget)

def expand_xgb_params(optuna_params, seed):
    return {
        'vect__max_df': optuna_params['vect_max_df'],
        'vect__min_df': optuna_params['vect_min_df'],
        'vect__ngram_range': tuple(map(int, optuna_params['vect_ngram_range'].split(','))),
        'tfidf__use_idf': optuna_params['tfidf_use_idf'],
        'clf__n_estimators': optuna_params['xgb_n_estimators'],
        'clf__max_depth': optuna_params['xgb_max_depth'],
        'clf__learning_rate': optuna_params['xgb_learning_rate'],
        'clf__subsample': optuna_params['xgb_subsample'],
        'clf__colsample_bytree': optuna_params['xgb_colsample_bytree'],
        'clf__reg_alpha': optuna_params['xgb_reg_alpha'],
        'clf__reg_lambda': optuna_params['xgb_reg_lambda'],
        'clf__scale_pos_weight': scale_pos_weight,
        'clf__random_state': seed
    }

best_params_expanded = expand_xgb_params(xgb_study.best_params, SEED)
xgb_model = xgb_pipeline.set_params(**best_params_expanded)
# Out:
# [I 2025-03-26 23:38:52,334] A new study created in RDB with name: xgb_optimization_lang_spa_model_ml_stem_False_lem_True_dup_False
# [I 2025-03-26 23:39:03,221] Trial 0 finished with value: 0.7403614806585939 and parameters: {'vect_max_df': 0.6982109220775343, 'vect_min_df': 3, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'xgb_n_estimators': 196, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.19295792934091066, 'xgb_subsample': 0.8082390952536007, 'xgb_colsample_bytree': 0.9585333734781921, 'xgb_reg_alpha': 2.6476698729459474e-06, 'xgb_reg_lambda': 9.867638589330041e-08}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:39:24,013] Trial 1 finished with value: 0.7370265238743763 and parameters: {'vect_max_df': 0.8948137608297146, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'xgb_n_estimators': 314, 'xgb_max_depth': 10, 'xgb_learning_rate': 0.045438755457014, 'xgb_subsample': 0.8284408073203631, 'xgb_colsample_bytree': 0.5607244381981831, 'xgb_reg_alpha': 0.0006881509588861034, 'xgb_reg_lambda': 0.061975598345648704}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:40:06,514] Trial 2 finished with value: 0.7083466878980333 and parameters: {'vect_max_df': 0.6756221701465204, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'xgb_n_estimators': 246, 'xgb_max_depth': 6, 'xgb_learning_rate': 0.369300776993427, 'xgb_subsample': 0.6233836257005214, 'xgb_colsample_bytree': 0.9878849252795923, 'xgb_reg_alpha': 0.03720074498816531, 'xgb_reg_lambda': 0.0008342468507783031}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:44:30,630] Trial 3 finished with value: 0.71895513360299 and parameters: {'vect_max_df': 0.5333994333489642, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'xgb_n_estimators': 347, 'xgb_max_depth': 15, 'xgb_learning_rate': 0.01507103484702493, 'xgb_subsample': 0.9790288193070696, 'xgb_colsample_bytree': 0.633236983250977, 'xgb_reg_alpha': 0.0003176582770076457, 'xgb_reg_lambda': 0.2115189769456}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:45:05,352] Trial 4 finished with value: 0.5550569813590542 and parameters: {'vect_max_df': 0.8272622770172439, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'xgb_n_estimators': 131, 'xgb_max_depth': 10, 'xgb_learning_rate': 0.005444147783201018, 'xgb_subsample': 0.8338360497107615, 'xgb_colsample_bytree': 0.8939176191253299, 'xgb_reg_alpha': 0.0016267306771569035, 'xgb_reg_lambda': 1.1361078041060394e-08}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:45:10,657] Trial 5 finished with value: 0.4098877432517085 and parameters: {'vect_max_df': 0.5865656422051242, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'xgb_n_estimators': 193, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.001897169706948543, 'xgb_subsample': 0.7069989067283378, 'xgb_colsample_bytree': 0.8268755724840955, 'xgb_reg_alpha': 0.22778254800985479, 'xgb_reg_lambda': 8.623035218546031e-05}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:46:40,699] Trial 6 finished with value: 0.7351168863966707 and parameters: {'vect_max_df': 0.8963311195691388, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'xgb_n_estimators': 500, 'xgb_max_depth': 15, 'xgb_learning_rate': 0.010575714113103256, 'xgb_subsample': 0.9289758713206547, 'xgb_colsample_bytree': 0.927051510158218, 'xgb_reg_alpha': 5.47765899787564e-06, 'xgb_reg_lambda': 0.0010352717845302738}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:47:24,604] Trial 7 finished with value: 0.695977384440585 and parameters: {'vect_max_df': 0.9122645721838045, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'xgb_n_estimators': 289, 'xgb_max_depth': 13, 'xgb_learning_rate': 0.0070838091223868775, 'xgb_subsample': 0.7799062880005964, 'xgb_colsample_bytree': 0.8933720096369581, 'xgb_reg_alpha': 0.7608920837624732, 'xgb_reg_lambda': 2.3951841587458957e-05}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:47:50,308] Trial 8 finished with value: 0.7366657910441254 and parameters: {'vect_max_df': 0.9571670053780259, 'vect_min_df': 3, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'xgb_n_estimators': 250, 'xgb_max_depth': 12, 'xgb_learning_rate': 0.06351211767265875, 'xgb_subsample': 0.99074711878646, 'xgb_colsample_bytree': 0.6893814110855516, 'xgb_reg_alpha': 0.32149328055531395, 'xgb_reg_lambda': 0.002053527364593385}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:48:15,256] Trial 9 finished with value: 0.7265266902524061 and parameters: {'vect_max_df': 0.9995746934796972, 'vect_min_df': 3, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'xgb_n_estimators': 202, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.026181128054296628, 'xgb_subsample': 0.8288989937579911, 'xgb_colsample_bytree': 0.951319077298511, 'xgb_reg_alpha': 0.0019699654873155275, 'xgb_reg_lambda': 0.00011687275543236193}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:48:16,777] Trial 10 finished with value: 0.6979561564335783 and parameters: {'vect_max_df': 0.726155843305788, 'vect_min_df': 5, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'xgb_n_estimators': 50, 'xgb_max_depth': 3, 'xgb_learning_rate': 0.36676271541852873, 'xgb_subsample': 0.5712592455598857, 'xgb_colsample_bytree': 0.7877522524341538, 'xgb_reg_alpha': 1.4181215843562187e-08, 'xgb_reg_lambda': 1.3165218125517593e-08}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:48:28,261] Trial 11 finished with value: 0.7386780130999886 and parameters: {'vect_max_df': 0.7833131073711719, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'xgb_n_estimators': 381, 'xgb_max_depth': 7, 'xgb_learning_rate': 0.09177950275984034, 'xgb_subsample': 0.7250652143871715, 'xgb_colsample_bytree': 0.518334495961881, 'xgb_reg_alpha': 1.2038897238910033e-05, 'xgb_reg_lambda': 5.592148102686059e-07}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:48:35,745] Trial 12 finished with value: 0.7342787271424972 and parameters: {'vect_max_df': 0.7974872007625287, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'xgb_n_estimators': 417, 'xgb_max_depth': 6, 'xgb_learning_rate': 0.12707882132554466, 'xgb_subsample': 0.680049283096021, 'xgb_colsample_bytree': 0.5071317331789174, 'xgb_reg_alpha': 3.014902333752392e-06, 'xgb_reg_lambda': 5.180293381973565e-07}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:48:44,414] Trial 13 finished with value: 0.7352459432183078 and parameters: {'vect_max_df': 0.643842920059567, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'xgb_n_estimators': 396, 'xgb_max_depth': 6, 'xgb_learning_rate': 0.1525118621316804, 'xgb_subsample': 0.7390974504881149, 'xgb_colsample_bytree': 0.6879672104373934, 'xgb_reg_alpha': 3.035590604397176e-06, 'xgb_reg_lambda': 9.930239657239255e-07}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:48:56,513] Trial 14 finished with value: 0.730743813165218 and parameters: {'vect_max_df': 0.7477244887922653, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'xgb_n_estimators': 470, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.12250967664058968, 'xgb_subsample': 0.5130581714173883, 'xgb_colsample_bytree': 0.7300086390598741, 'xgb_reg_alpha': 9.026966365004656e-08, 'xgb_reg_lambda': 4.544751460103706e-07}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:49:15,898] Trial 15 finished with value: 0.733360508761146 and parameters: {'vect_max_df': 0.8156947345102459, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'xgb_n_estimators': 368, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.060269242614028516, 'xgb_subsample': 0.8937098095482976, 'xgb_colsample_bytree': 0.8489241481705548, 'xgb_reg_alpha': 2.651218352376198e-07, 'xgb_reg_lambda': 3.814355337748084e-06}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:49:18,375] Trial 16 finished with value: 0.7236937388404592 and parameters: {'vect_max_df': 0.6762240963808956, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'xgb_n_estimators': 135, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.20647423715987206, 'xgb_subsample': 0.6417103027484647, 'xgb_colsample_bytree': 0.6052851371709772, 'xgb_reg_alpha': 3.770793154666737e-05, 'xgb_reg_lambda': 8.005843163905849e-08}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:49:33,575] Trial 17 finished with value: 0.7226765299709605 and parameters: {'vect_max_df': 0.5991699406231287, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'xgb_n_estimators': 142, 'xgb_max_depth': 8, 'xgb_learning_rate': 0.03469830032343791, 'xgb_subsample': 0.7734188124129358, 'xgb_colsample_bytree': 0.5078366862406202, 'xgb_reg_alpha': 3.642917308607612e-05, 'xgb_reg_lambda': 6.077165805400688e-06}. Best is trial 0 with value: 0.7403614806585939.
# [I 2025-03-26 23:49:53,775] Trial 18 finished with value: 0.7432361485508452 and parameters: {'vect_max_df': 0.7718785075634825, 'vect_min_df': 3, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'xgb_n_estimators': 442, 'xgb_max_depth': 7, 'xgb_learning_rate': 0.08660697715168425, 'xgb_subsample': 0.8796948394950371, 'xgb_colsample_bytree': 0.7722149975331588, 'xgb_reg_alpha': 6.581354345292251e-07, 'xgb_reg_lambda': 1.62756697933325e-07}. Best is trial 18 with value: 0.7432361485508452.
# [I 2025-03-26 23:49:56,509] Trial 19 finished with value: 0.730863997066514 and parameters: {'vect_max_df': 0.7084758872663127, 'vect_min_df': 4, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'xgb_n_estimators': 53, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.25053584987573185, 'xgb_subsample': 0.9083245389805301, 'xgb_colsample_bytree': 0.7678125466207891, 'xgb_reg_alpha': 4.719840976948612e-07, 'xgb_reg_lambda': 6.511510761809336e-08}. Best is trial 18 with value: 0.7432361485508452.
# [I 2025-03-26 23:51:51,916] Trial 20 finished with value: 0.4663124267824211 and parameters: {'vect_max_df': 0.8536234786358388, 'vect_min_df': 3, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'xgb_n_estimators':
 'vect_min_df': 5, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'xgb_n_estimators': 369, 'xgb_max_depth': 7, 'xgb_learning_rate': 0.3103824825182614, 'xgb_subsample': 0.9579790100087202, 'xgb_colsample_bytree': 0.902984005367867, 'xgb_reg_alpha': 5.15372526278119e-05, 'xgb_reg_lambda': 4.7217921402519303e-07}. Best is trial 83 with value: 0.7537182996375378.
# [I 2025-03-27 00:05:04,563] Trial 96 finished with value: 0.7210585912790028 and parameters: {'vect_max_df': 0.7265503984752119, 'vect_min_df': 5, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'xgb_n_estimators': 282, 'xgb_max_depth': 14, 'xgb_learning_rate': 0.22175720118280634, 'xgb_subsample': 0.9469669998194231, 'xgb_colsample_bytree': 0.8319965736325656, 'xgb_reg_alpha': 2.2603533092415874e-05, 'xgb_reg_lambda': 1.9566786480710457e-07}. Best is trial 83 with value: 0.7537182996375378.
# [I 2025-03-27 00:05:11,478] Trial 97 finished with value: 0.7373978174843833 and parameters: {'vect_max_df': 0.7409240394820856, 'vect_min_df': 5, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'xgb_n_estimators': 308, 'xgb_max_depth': 6, 'xgb_learning_rate': 0.18045171682285657, 'xgb_subsample': 0.9732714684170546, 'xgb_colsample_bytree': 0.6990336661029342, 'xgb_reg_alpha': 0.00010555155217406365, 'xgb_reg_lambda': 1.0339218125974034e-07}. Best is trial 83 with value: 0.7537182996375378.
# [I 2025-03-27 00:05:16,907] Trial 98 finished with value: 0.7204392495210055 and parameters: {'vect_max_df': 0.7868208700990929, 'vect_min_df': 5, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'xgb_n_estimators': 326, 'xgb_max_depth': 4, 'xgb_learning_rate': 0.3986235145122357, 'xgb_subsample': 0.5302975238869492, 'xgb_colsample_bytree': 0.9694309348501768, 'xgb_reg_alpha': 0.5831767286008257, 'xgb_reg_lambda': 7.864099838145224e-07}. Best is trial 83 with value: 0.7537182996375378.
# [I 2025-03-27 00:05:25,062] Trial 99 finished with value: 0.6803971447209509 and parameters: {'vect_max_df': 0.9914574252493178, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'xgb_n_estimators': 277, 'xgb_max_depth': 5, 'xgb_learning_rate': 0.009456046769136112, 'xgb_subsample': 0.647195021529091, 'xgb_colsample_bytree': 0.7282455997451944, 'xgb_reg_alpha': 0.0001878640140013554, 'xgb_reg_lambda': 0.09514394740823856}. Best is trial 83 with value: 0.7537182996375378.

# %%
group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
cv_results = cross_validate(xgb_model, X_train, y_train_enc, cv=cv, scoring=scoring, n_jobs=J_JOBS)

xgb_model.fit(X_train, y_train_enc)

acc = np.mean(cv_results['test_accuracy'])
pre = np.mean(cv_results['test_precision_macro'])
rec = np.mean(cv_results['test_recall_macro'])
f1_ = np.mean(cv_results['test_f1_macro'])

xgb_best_trial = xgb_study.best_trial
print("Best trial Cross-Validation results on the training set for XGBoost:")
print(f"  Accuracy:  {acc:.4f}")
print(f"  Precision: {pre:.4f}")
print(f"  Recall:    {rec:.4f}")
print(f"  F1:        {f1_:.4f}")

print("Best hyperparameters:")
for key, value in xgb_best_trial.params.items():
    print(f"  {key}: {value}")

model_filename = 'objects/task_1/models/best_xgb_{}_{}.pkl'.format(
    file_name,
    data_config
)
joblib.dump(xgb_model, model_filename)
print(f"XGBoost model saved as {model_filename}.")

task_val   = "task_1"
model_name = "XGBoost"
eval_type  = "inner"

save_eval_results(DB_PATH, db_file_name, task_val, model_name, eval_type, acc, pre, rec, f1_, xgb_study_name, json.dumps(xgb_study.best_params),language)
# Out:
# c:\Users\sebas\Escritorio\Python_env\NLP\lib\site-packages\xgboost\training.py:183: UserWarning: [00:05:32] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best trial Cross-Validation results on the training set for XGBoost:
#   Accuracy:  0.8116
#   Precision: 0.7993
#   Recall:    0.7347
#   F1:        0.7537
# Best hyperparameters:
#   vect_max_df: 0.7199787513631403
#   vect_min_df: 5
#   vect_ngram_range: 1,2
#   tfidf_use_idf: True
#   xgb_n_estimators: 307
#   xgb_max_depth: 5
#   xgb_learning_rate: 0.1197967376271997
#   xgb_subsample: 0.9050577967673583
#   xgb_colsample_bytree: 0.8503754664707338
#   xgb_reg_alpha: 0.00015171620911956087
#   xgb_reg_lambda: 1.0737553932642062e-06
# XGBoost model saved as objects/task_1/models/best_xgb_lang_spa_model_ml_stem_False_lem_True_dup_False.pkl.
#
# Inserted CV results into 'eval' table in tfm.db.

# %% [markdown]
# ### Logistic Regression

# %%
lr_pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', LogisticRegression())  
])

def lr_objective(trial):
    group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
    cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
    max_df = trial.suggest_float('vect_max_df', 0.5, 1.0)
    min_df = trial.suggest_int('vect_min_df', 1, 5)
    ngram_range_str = trial.suggest_categorical('vect_ngram_range', ["1,1", "1,2"])
    ngram_range = tuple(map(int, ngram_range_str.split(',')))
    
    use_idf = trial.suggest_categorical('tfidf_use_idf', [True, False])
    
    C = trial.suggest_float('lr_C', 1e-3, 10, log=True)
    penalty = trial.suggest_categorical('lr_penalty', ['l2', 'l1', 'elasticnet', 'none'])
    
    if penalty == 'none':
        penalty_value = None
    else:
        penalty_value = penalty
    
    solver = trial.suggest_categorical('lr_solver', ['lbfgs', 'sag', 'saga'])
    
    if penalty in ['l1', 'elasticnet'] and solver != 'saga':
        raise optuna.TrialPruned("Solver must be 'saga' for l1 or elasticnet penalty.")
    
    params = {
        'vect__max_df': max_df,
        'vect__min_df': min_df,
        'vect__ngram_range': ngram_range,
        'tfidf__use_idf': use_idf,
        'clf__C': C,
        'clf__penalty': penalty_value,
        'clf__solver': solver,
        'clf__class_weight': 'balanced',
        'clf__random_state': SEED,
        'clf__max_iter': 1000
    }
    
    if penalty == 'elasticnet':
        l1_ratio = trial.suggest_float('lr_l1_ratio', 0.0, 1.0)
        params['clf__l1_ratio'] = l1_ratio
        
    lr_pipe = lr_pipeline.set_params(**params)
    scores = cross_val_score(lr_pipe, X_train, y_train_enc, cv=cv, scoring='f1_macro', n_jobs=J_JOBS)
    return np.mean(scores)

lr_study_name = 'lr_optimization_{}_{}'.format(file_name, data_config)
storage_name = f"sqlite:///objects/task_1/studies/{lr_study_name}.db"
lr_study = optuna.create_study(
    study_name=lr_study_name,
    storage=storage_name,
    direction="maximize",
    load_if_exists=True,
    sampler=optuna.samplers.TPESampler(seed=SEED)
)

budget = 100
lr_study.optimize(lr_objective, n_trials=budget)

def expand_lr_params(optuna_params, seed):
    expanded = {
        'vect__max_df': optuna_params['vect_max_df'],
        'vect__min_df': optuna_params['vect_min_df'],
        'vect__ngram_range': tuple(map(int, optuna_params['vect_ngram_range'].split(','))),
        'tfidf__use_idf': optuna_params['tfidf_use_idf'],
        'clf__C': optuna_params['lr_C'],
        'clf__penalty': None if optuna_params['lr_penalty'] == 'none' else optuna_params['lr_penalty'],
        'clf__solver': optuna_params['lr_solver'],
        'clf__class_weight': 'balanced',
        'clf__random_state': seed,
        'clf__max_iter': 1000
    }
    if optuna_params['lr_penalty'] == 'elasticnet':
        expanded['clf__l1_ratio'] = optuna_params['lr_l1_ratio']
    return expanded

best_params_expanded = expand_lr_params(lr_study.best_params, SEED)
lr_model = lr_pipeline.set_params(**best_params_expanded)
# Out:
# [I 2025-03-27 00:05:36,664] A new study created in RDB with name: lr_optimization_lang_spa_model_ml_stem_False_lem_True_dup_False
# [I 2025-03-27 00:05:38,843] Trial 0 finished with value: 0.6990686696564321 and parameters: {'vect_max_df': 0.6982109220775343, 'vect_min_df': 3, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'lr_C': 0.019988774029355096, 'lr_penalty': 'none', 'lr_solver': 'saga'}. Best is trial 0 with value: 0.6990686696564321.
# [I 2025-03-27 00:05:38,909] Trial 1 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:05:42,756] Trial 2 finished with value: 0.7183755836405268 and parameters: {'vect_max_df': 0.8763273029713101, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'lr_C': 8.844814857004613, 'lr_penalty': 'l1', 'lr_solver': 'saga'}. Best is trial 2 with value: 0.7183755836405268.
# [I 2025-03-27 00:05:45,091] Trial 3 finished with value: 0.7374380244031846 and parameters: {'vect_max_df': 0.8338890653642945, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'lr_C': 6.795642980268708, 'lr_penalty': 'elasticnet', 'lr_solver': 'saga', 'lr_l1_ratio': 0.22955030121591957}. Best is trial 3 with value: 0.7374380244031846.
# [I 2025-03-27 00:05:47,343] Trial 4 finished with value: 0.6932974050987643 and parameters: {'vect_max_df': 0.9915825645442211, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'lr_C': 0.403327494371126, 'lr_penalty': 'none', 'lr_solver': 'saga'}. Best is trial 3 with value: 0.7374380244031846.
# [I 2025-03-27 00:05:48,226] Trial 5 finished with value: 0.7070123884980022 and parameters: {'vect_max_df': 0.6586598003677828, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'lr_C': 0.09286029947478121, 'lr_penalty': 'l2', 'lr_solver': 'saga'}. Best is trial 3 with value: 0.7374380244031846.
# [I 2025-03-27 00:05:48,276] Trial 6 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:05:48,326] Trial 7 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:05:48,693] Trial 8 finished with value: 0.7247652701035779 and parameters: {'vect_max_df': 0.99074711878646, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'lr_C': 0.007624608303792285, 'lr_penalty': 'l2', 'lr_solver': 'saga'}. Best is trial 3 with value: 0.7374380244031846.
# [I 2025-03-27 00:05:49,059] Trial 9 finished with value: 0.7324571245036251 and parameters: {'vect_max_df': 0.951319077298511, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'lr_C': 0.004193598747260992, 'lr_penalty': 'l2', 'lr_solver': 'sag'}. Best is trial 3 with value: 0.7374380244031846.
# [I 2025-03-27 00:05:49,126] Trial 10 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:05:49,192] Trial 11 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:05:49,259] Trial 12 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:05:49,610] Trial 13 finished with value: 0.7336307471070359 and parameters: {'vect_max_df': 0.9101840131265813, 'vect_min_df': 4, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'lr_C': 7.821630543596568, 'lr_penalty': 'l2', 'lr_solver': 'sag'}. Best is trial 3 with value: 0.7374380244031846.
# [I 2025-03-27 00:05:49,959] Trial 14 finished with value: 0.7350790511158203 and parameters: {'vect_max_df': 0.7851794180964736, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'lr_C': 4.462742725153962, 'lr_penalty': 'l2', 'lr_solver': 'sag'}. Best is trial 3 with value: 0.7374380244031846.
# [I 2025-03-27 00:05:50,643] Trial 15 finished with value: 0.7336411609055496 and parameters: {'vect_max_df': 0.7926457254400081, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'lr_C': 1.3687385445190619, 'lr_penalty': 'elasticnet', 'lr_solver': 'saga', 'lr_l1_ratio': 0.19545293635088098}. Best is trial 3 with value: 0.7374380244031846.
# [I 2025-03-27 00:05:50,709] Trial 16 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:05:51,042] Trial 17 finished with value: 0.7443908657249766 and parameters: {'vect_max_df': 0.5756715551406155, 'vect_min_df': 3, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'lr_C': 0.6688443334679836, 'lr_penalty': 'l2', 'lr_solver': 'sag'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:05:57,776] Trial 18 finished with value: 0.7395791710465834 and parameters: {'vect_max_df': 0.5273453409866513, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.5450555013224008, 'lr_penalty': 'none', 'lr_solver': 'saga'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:05:58,393] Trial 19 finished with value: 0.7127419749859544 and parameters: {'vect_max_df': 0.5094864110300015, 'vect_min_df': 3, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.5781432054194782, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:06:01,084] Trial 20 finished with value: 0.7233095441220404 and parameters: {'vect_max_df': 0.5831579836082287, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.03978394888711363, 'lr_penalty': 'none', 'lr_solver': 'saga'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:06:07,808] Trial 21 finished with value: 0.7387904754531341 and parameters: {'vect_max_df': 0.5920181406600192, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.7390431280088008, 'lr_penalty': 'none', 'lr_solver': 'saga'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:06:14,843] Trial 22 finished with value: 0.7387904754531341 and parameters: {'vect_max_df': 0.590376755649477, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.8400991462355987, 'lr_penalty': 'none', 'lr_solver': 'saga'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:06:21,741] Trial 23 finished with value: 0.7387904754531341 and parameters: {'vect_max_df': 0.5983699813166308, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.19360107210828303, 'lr_penalty': 'none', 'lr_solver': 'saga'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:06:24,276] Trial 24 finished with value: 0.7214185685027943 and parameters: {'vect_max_df': 0.5499176322799494, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.2129041472772676, 'lr_penalty': 'none', 'lr_solver': 'saga'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:06:30,459] Trial 25 finished with value: 0.7312747180504449 and parameters: {'vect_max_df': 0.6201670301895611, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.9562477036169584, 'lr_penalty': 'none', 'lr_solver': 'sag'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:06:31,126] Trial 26 finished with value: 0.718963918826144 and parameters: {'vect_max_df': 0.5020981743601198, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'lr_C': 0.4263097360332956, 'lr_penalty': 'l2', 'lr_solver': 'saga'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:06:33,197] Trial 27 finished with value: 0.7044736124584541 and parameters: {'vect_max_df': 0.5533963836969082, 'vect_min_df': 3, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 2.532025321290989, 'lr_penalty': 'none', 'lr_solver': 'saga'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:06:34,413] Trial 28 finished with value: 0.7415098530668889 and parameters: {'vect_max_df': 0.6302541209727158, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.052397946337080566, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:06:35,060] Trial 29 finished with value: 0.6986115065186453 and parameters: {'vect_max_df': 0.7110384737985898, 'vect_min_df': 5, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'lr_C': 0.03170100598684273, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:06:35,674] Trial 30 finished with value: 0.7294082304959668 and parameters: {'vect_max_df': 0.6332546349699412, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.055102383613730245, 'lr_penalty': 'l2', 'lr_solver': 'lbfgs'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:06:36,860] Trial 31 finished with value: 0.7425102203320266 and parameters: {'vect_max_df': 0.549931778416546, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.1924860181064668, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:06:38,035] Trial 32 finished with value: 0.738370059425802 and parameters: {'vect_max_df': 0.5374184526623498, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.16244947630547668, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 17 with value: 0.7443908657249766.
# [I 2025-03-27 00:06:39,186] Trial 33 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.6982522095406092, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.11833003575303867, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:40,361] Trial 34 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.705200481211397, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.019308065955636153, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:40,425] Trial 35 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:06:41,693] Trial 36 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7238559590246013, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.12300778738943847, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:42,330] Trial 37 finished with value: 0.7159907715559664 and parameters: {'vect_max_df': 0.7280915109527523, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'lr_C': 0.013380766908520646, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:42,410] Trial 38 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:06:43,053] Trial 39 finished with value: 0.7256696247138807 and parameters: {'vect_max_df': 0.6791554526637495, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'lr_C': 0.32246552126819056, 'lr_penalty': 'l2', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:43,425] Trial 40 finished with value: 0.7130114549821551 and parameters: {'vect_max_df': 0.7255731444232002, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'lr_C': 0.10179961820243325, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:44,591] Trial 41 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.670136294193348, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.14530677365346054, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:45,754] Trial 42 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.6837730548293873, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.075754626957579, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:46,979] Trial 43 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.6718494702621428, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.06531181281950199, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:48,160] Trial 44 finished with value: 0.7412845322279225 and parameters: {'vect_max_df': 0.653294479731598, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.12399116299793375, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:49,324] Trial 45 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.6853502912764111, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.022874208802826902, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:50,497] Trial 46 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7700707672227225, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.007745420607145089, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:51,838] Trial 47 finished with value: 0.7221459198881366 and parameters: {'vect_max_df': 0.806696492109708, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'lr_C': 0.06830531341264562, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:51,918] Trial 48 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:06:52,543] Trial 49 finished with value: 0.7314731387276379 and parameters: {'vect_max_df': 0.6542020733933757, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.012069261302163141, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:53,767] Trial 50 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7028669171471101, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.03424103373508141, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:54,951] Trial 51 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.671020247571638, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.06586809764988501, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:56,152] Trial 52 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7162597735301565, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.13191468785866683, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:57,339] Trial 53 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.6887524266245525, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.07904090967859849, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:57,419] Trial 54 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:06:58,618] Trial 55 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7396629957416441, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.00556270207254138, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:06:59,852] Trial 56 finished with value: 0.7415098530668889 and parameters: {'vect_max_df': 0.61798411159369, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.01913711528322494, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:00,452] Trial 57 finished with value: 0.7339459547492091 and parameters: {'vect_max_df': 0.6732238196847136, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.357835498511461, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:01,658] Trial 58 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.8080416181677618, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.16567784234772584, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:01,741] Trial 59 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:07:01,823] Trial 60 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:07:03,056] Trial 61 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.6892390436444763, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.02074722031086607, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:04,240] Trial 62 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.6934911736291247, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.04679756363199412, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:05,449] Trial 63 finished with value: 0.7404308411654593 and parameters: {'vect_max_df': 0.6410065856003886, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.08328465660887142, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:06,608] Trial 64 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.6757100878032112, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.010543754958126084, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:07,797] Trial 65 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7191321957960247, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.017831564222796126, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:09,207] Trial 66 finished with value: 0.7041202834059445 and parameters: {'vect_max_df': 0.6662593701958581, 'vect_min_df': 2, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'lr_C': 0.24154967326992763, 'lr_penalty': 'none', 'lr_solver': 'sag'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:10,351] Trial 67 finished with value: 0.7415098530668889 and parameters: {'vect_max_df': 0.6169164788149695, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.13423824548268046, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:11,558] Trial 68 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.6996820121845504, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.06469071733181883, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:12,209] Trial 69 finished with value: 0.7261676141416566 and parameters: {'vect_max_df': 0.6056443289464607, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.0292193749039412, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:12,288] Trial 70 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:07:13,497] Trial 71 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7754312561126456, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.007134545302384792, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:14,721] Trial 72 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7472041179553583, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.003610479926432724, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:15,945] Trial 73 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7641823691272902, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.009556336311357981, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:17,188] Trial 74 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.851526888223141, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.016236755566179498, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:18,368] Trial 75 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7997778195452451, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.008164851850160254, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:18,686] Trial 76 finished with value: 0.6880702336362907 and parameters: {'vect_max_df': 0.7319313886564621, 'vect_min_df': 5, 'vect_ngram_range': '1,1', 'tfidf_use_idf': False, 'lr_C': 0.052639512821376036, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:19,700] Trial 77 finished with value: 0.7376776908471173 and parameters: {'vect_max_df': 0.6646342977941909, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.10128418777259769, 'lr_penalty': 'l2', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:20,945] Trial 78 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.6849228858021712, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.004194365367311448, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:21,610] Trial 79 finished with value: 0.726070802634205 and parameters: {'vect_max_df': 0.6347107611295049, 'vect_min_df': 2, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.14558765438554958, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:21,696] Trial 80 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:07:22,945] Trial 81 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7022069098388404, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.02652384686637847, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:24,184] Trial 82 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7006112036559078, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.03973531470886414, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:25,378] Trial 83 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.6595280320406962, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.06989531329892508, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:26,554] Trial 84 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7417460132904711, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.11063098131709329, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:33,611] Trial 85 finished with value: 0.7363779335169045 and parameters: {'vect_max_df': 0.9261091829581476, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.02413388977010842, 'lr_penalty': 'none', 'lr_solver': 'saga'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:34,876] Trial 86 finished with value: 0.7412845322279225 and parameters: {'vect_max_df': 0.6461385438713849, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.014304695869673844, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:36,880] Trial 87 finished with value: 0.7113028298317516 and parameters: {'vect_max_df': 0.7212812709220981, 'vect_min_df': 1, 'vect_ngram_range': '1,1', 'tfidf_use_idf': True, 'lr_C': 0.039332394895463044, 'lr_penalty': 'none', 'lr_solver': 'sag'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:37,560] Trial 88 finished with value: 0.7047057125533305 and parameters: {'vect_max_df': 0.6811109761196111, 'vect_min_df': 4, 'vect_ngram_range': '1,2', 'tfidf_use_idf': False, 'lr_C': 0.054795568967436405, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:38,436] Trial 89 finished with value: 0.7419361793657793 and parameters: {'vect_max_df': 0.7844681084081302, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.26511496645757165, 'lr_penalty': 'l2', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:38,499] Trial 90 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:07:39,702] Trial 91 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.6701896070813063, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.07866245901787053, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:40,859] Trial 92 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.6861223442474624, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.09130654839638995, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:42,034] Trial 93 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7268393467312642, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.0629716418806514, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:43,214] Trial 94 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7092049209497362, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.04394449032848328, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:44,405] Trial 95 finished with value: 0.7440630694216233 and parameters: {'vect_max_df': 0.656393383468444, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.12217038377508936, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:45,597] Trial 96 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7579672870167198, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.03083746200556271, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:45,677] Trial 97 pruned. Solver must be 'saga' for l1 or elasticnet penalty.
# [I 2025-03-27 00:07:46,852] Trial 98 finished with value: 0.7459149487940026 and parameters: {'vect_max_df': 0.7005555793651483, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.0888471335435129, 'lr_penalty': 'none', 'lr_solver': 'lbfgs'}. Best is trial 33 with value: 0.7459149487940026.
# [I 2025-03-27 00:07:53,752] Trial 99 finished with value: 0.7362600498422823 and parameters: {'vect_max_df': 0.6309544300172423, 'vect_min_df': 1, 'vect_ngram_range': '1,2', 'tfidf_use_idf': True, 'lr_C': 0.021309749657662105, 'lr_penalty': 'none', 'lr_solver': 'saga'}. Best is trial 33 with value: 0.7459149487940026.

# %%
group_kfold = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=SEED)
cv = group_kfold.split(X_train, y_train_enc, groups=groups_train)
cv_results = cross_validate(lr_model, X_train, y_train_enc, cv=cv, scoring=scoring, n_jobs=J_JOBS)

lr_model.fit(X_train, y_train_enc)

acc = np.mean(cv_results['test_accuracy'])
pre = np.mean(cv_results['test_precision_macro'])
rec = np.mean(cv_results['test_recall_macro'])
f1_ = np.mean(cv_results['test_f1_macro'])

lr_best_trial = lr_study.best_trial
print("Best trial Cross-Validation results on the training set for Logistic Regression:")
print(f"  Accuracy:  {acc:.4f}")
print(f"  Precision: {pre:.4f}")
print(f"  Recall:    {rec:.4f}")
print(f"  F1:        {f1_:.4f}")

print("Best hyperparameters:")
for key, value in lr_best_trial.params.items():
    print(f"  {key}: {value}")

model_filename = 'objects/task_1/models/best_lr_{}_{}.pkl'.format(
    file_name,
    data_config
)
joblib.dump(lr_model, model_filename)
print(f"Logistic Regression model saved as {model_filename}.")

task_val   = "task_1"
model_name = "Logistic Regression"
eval_type  = "inner"

save_eval_results(DB_PATH, db_file_name, task_val, model_name, eval_type, acc, pre, rec, f1_, lr_study_name, json.dumps(lr_study.best_params),language)
# Out:
# c:\Users\sebas\Escritorio\Python_env\NLP\lib\site-packages\sklearn\linear_model\_logistic.py:1196: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=None)
#   warnings.warn(
# c:\Users\sebas\Escritorio\Python_env\NLP\lib\site-packages\sklearn\linear_model\_logistic.py:1207: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# Best trial Cross-Validation results on the training set for Logistic Regression:
#   Accuracy:  0.7950
#   Precision: 0.7626
#   Recall:    0.7363
#   F1:        0.7459
# Best hyperparameters:
#   vect_max_df: 0.6982522095406092
#   vect_min_df: 1
#   vect_ngram_range: 1,2
#   tfidf_use_idf: True
#   lr_C: 0.11833003575303867
#   lr_penalty: none
#   lr_solver: lbfgs
# Logistic Regression model saved as objects/task_1/models/best_lr_lang_spa_model_ml_stem_False_lem_True_dup_False.pkl.
#
# Inserted CV results into 'eval' table in tfm.db.

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Random Forest

# %%
# Outer evaluation for Random Forest
y_pred_rf = rf_model.predict(X_test)
acc_rf = accuracy_score(y_test_enc, y_pred_rf)
pre_rf = precision_score(y_test_enc, y_pred_rf, average='macro')
rec_rf = recall_score(y_test_enc, y_pred_rf, average='macro')
f1_rf = f1_score(y_test_enc, y_pred_rf, average='macro')

print("\nOuter evaluation results for Random Forest:")
print(f"  Accuracy:  {acc_rf:.4f}")
print(f"  Precision: {pre_rf:.4f}")
print(f"  Recall:    {rec_rf:.4f}")
print(f"  F1:        {f1_rf:.4f}")

save_eval_results(DB_PATH, db_file_name, 
                  task_val="task_1", 
                  model_name="Random Forest", 
                  eval_type="outer", 
                  acc=acc_rf, pre=pre_rf, rec=rec_rf, f1_=f1_rf, 
                  study_name=rf_study_name, 
                  params=json.dumps(rf_study.best_params),
                  lang=language)
# Out:
# Outer evaluation results for Random Forest:
#   Accuracy:  0.7682
#   Precision: 0.7843
#   Recall:    0.7752
#   F1:        0.7673
#
# Inserted CV results into 'eval' table in tfm.db.

# %% [markdown]
# ### SVM

# %%
# Outer evaluation for SVM
y_pred_svm = svm_model.predict(X_test)
acc_svm = accuracy_score(y_test_enc, y_pred_svm)
pre_svm = precision_score(y_test_enc, y_pred_svm, average='macro')
rec_svm = recall_score(y_test_enc, y_pred_svm, average='macro')
f1_svm = f1_score(y_test_enc, y_pred_svm, average='macro')

print("\nOuter evaluation results for SVM:")
print(f"  Accuracy:  {acc_svm:.4f}")
print(f"  Precision: {pre_svm:.4f}")
print(f"  Recall:    {rec_svm:.4f}")
print(f"  F1:        {f1_svm:.4f}")

save_eval_results(DB_PATH, db_file_name, 
                  task_val="task_1", 
                  model_name="SVM", 
                  eval_type="outer", 
                  acc=acc_svm, pre=pre_svm, rec=rec_svm, f1_=f1_svm, 
                  study_name=svm_study_name, 
                  params=json.dumps(svm_study.best_params),
                  lang=language)

# %% [markdown]
# ### XGBoost

# %%
# Outer evaluation for XGBoost
y_pred_xgb = xgb_model.predict(X_test)
acc_xgb = accuracy_score(y_test_enc, y_pred_xgb)
pre_xgb = precision_score(y_test_enc, y_pred_xgb, average='macro')
rec_xgb = recall_score(y_test_enc, y_pred_xgb, average='macro')
f1_xgb = f1_score(y_test_enc, y_pred_xgb, average='macro')

print("\nOuter evaluation results for XGBoost:")
print(f"  Accuracy:  {acc_xgb:.4f}")
print(f"  Precision: {pre_xgb:.4f}")
print(f"  Recall:    {rec_xgb:.4f}")
print(f"  F1:        {f1_xgb:.4f}")

save_eval_results(DB_PATH, db_file_name, 
                  task_val="task_1", 
                  model_name="XGBoost", 
                  eval_type="outer", 
                  acc=acc_xgb, pre=pre_xgb, rec=rec_xgb, f1_=f1_xgb, 
                  study_name=xgb_study_name, 
                  params=json.dumps(xgb_study.best_params),
                  lang=language)

# %% [markdown]
# ### Logistic Regression

# %%
# Outer evaluation for Logistic Regression
y_pred_lr = lr_model.predict(X_test)
acc_lr = accuracy_score(y_test_enc, y_pred_lr)
pre_lr = precision_score(y_test_enc, y_pred_lr, average='macro')
rec_lr = recall_score(y_test_enc, y_pred_lr, average='macro')
f1_lr = f1_score(y_test_enc, y_pred_lr, average='macro')

print("Outer evaluation results for Logistic Regression:")
print(f"  Accuracy:  {acc_lr:.4f}")
print(f"  Precision: {pre_lr:.4f}")
print(f"  Recall:    {rec_lr:.4f}")
print(f"  F1:        {f1_lr:.4f}")


save_eval_results(DB_PATH, db_file_name, 
                  task_val="task_1", 
                  model_name="Logistic Regression", 
                  eval_type="outer", 
                  acc=acc_lr, pre=pre_lr, rec=rec_lr, f1_=f1_lr, 
                  study_name=lr_study_name, 
                  params=json.dumps(lr_study.best_params))
# Out:
# Outer evaluation results for Logistic Regression:
#   Accuracy:  0.7743
#   Precision: 0.7332
#   Recall:    0.7235
#   F1:        0.7279
#
# Inserted CV results into 'eval' table in tfm.db.
#
# Outer evaluation results for Random Forest:
#   Accuracy:  0.7981
#   Precision: 0.7625
#   Recall:    0.7516
#   F1:        0.7565
#
# Inserted CV results into 'eval' table in tfm.db.
#
# Outer evaluation results for SVM:
#   Accuracy:  0.7862
#   Precision: 0.7478
#   Recall:    0.7386
#   F1:        0.7428
#
# Inserted CV results into 'eval' table in tfm.db.
#
# Outer evaluation results for XGBoost:
#   Accuracy:  0.7838
#   Precision: 0.7494
#   Recall:    0.7149
#   F1:        0.7271
#
# Inserted CV results into 'eval' table in tfm.db.
